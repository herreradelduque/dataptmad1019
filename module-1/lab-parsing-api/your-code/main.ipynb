# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here

#  Web used:
'https://www.zalando.fr/promo-homme/'
# Out:
# 'https://www.zalando.fr/promo-homme/'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# url with 1st page of data:
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=0&sort=popularity'

# headers:
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %%
response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 55967,
#  'pagination': {'page_count': 667, 'current_page': 1, 'per_page': 84},
#  'sort': 'popularity',
#  'articles': [{'sku': 'TOB22O01B-Q11',
#    'name': 'ORIGINAL SLIM FIT - T-shirt à manches longues - black',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-jeans-original-t-shirt-a-manches-longues-black-tob22o01b-q11',
#    'media': [{'path': 'TO/B2/2O/01/BQ/11/TOB22O01B-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/2O/01/BQ/11/TOB22O01B-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TOB22O04X-Q11',
#    'name': 'BADGE TEE - T-shirt basique - black',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '19,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-jeans-badge-tee-t-shirt-basique-tob22o04x-q11',
#    'media': [{'path': 'TO/B2/2O/04/XQ/11/TOB22O04X-Q11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/2O/04/XQ/11/TOB22O04X-Q11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA215B000-Q12',
#    'name': 'OLD SKOOL - Chaussures de skate - black',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '67,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['34.5',
#     '35',
#     '36',
#     '36.5',
#     '37',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '47',
#     '48',
#     '49',
#     '50'],
#    'url_key': 'vans-old-skool-baskets-basses-va215b000-q12',
#    'media': [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-10%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'outfits': [{'id': 'nmnnhTu7SCu',
#      'url_key': '/outfits/nmnnhTu7SCu',
#      'media': [{'path': 'd1bd2777cfc5454a9d911d1910dc9124/6c067440d6274d20a8cab429b32260c4.jpeg',
#        'outline_reference': 'outfit_image'}],
#      'source': 'ceb1a7b8-e53d-488f-a81e-19158b7316d9',
#      'gender': 'men',
#      'creator': {'id': 'a5991f03-b377-42e2-bfed-fb73fa7aab4a',
#       'name': 'Styled by Zalando',
#       'media': [{'path': '82ab4f0ada9742cb8a2feb029a66a7d1/f0e911d245c04ef48fe0d7677fd7b787.png',
#         'outline_reference': 'creator_image'}]},
#      'items': [{'id': 'JAL22T00C-N11'},
#       {'id': 'JA222O2OU-A11'},
#       {'id': 'LEF22G005-Q11'},
#       {'id': 'VA215B000-Q12'},
#       {'id': 'OB052O001-Q11'},
#       {'id': 'YO152H04W-M11'},
#       {'id': 'C5154C00P-A11'}]}],
#    'delivery_promises': []},
#   {'sku': 'PI922EA0O-K11',
#    'name': 'Chino - dark blue',
#    'price': {'original': '29,99\xa0€',
#     'promotional': '16,49\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['29', '30', '31', '32', '33', '34'],
#    'url_key': 'pier-one-chino-dark-blue-pi922ea0o-k11',
#    'media': [{'path': 'PI/92/2E/A0/OK/11/PI922EA0O-K11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'PI/92/2E/A0/OK/11/PI922EA0O-K11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Pier One',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O0AY-Q11',
#    'name': 'AIR MAX 97  - Baskets basses - anthracite/volt/electric green/cool grey',
#    'price': {'original': '169,95\xa0€',
#     'promotional': '101,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-air-max-97-baskets-basses-anthracitevoltelectric-greencool-grey-ni112o0ay-q11',
#    'media': [{'path': 'NI/11/2O/0A/YQ/11/NI112O0AY-Q11@5.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA222D01Y-002',
#    'name': 'T-shirt basique - white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-regular-fit-t-shirt-basique-la222d01y-002',
#    'media': [{'path': 'LA/22/2D/01/Y0/02/LA222D01Y-002@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2D/01/Y0/02/LA222D01Y-002@16.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O0AJ-Q12',
#    'name': 'REACT 55 SE - Baskets basses - black/white',
#    'price': {'original': '129,95\xa0€',
#     'promotional': '77,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36.5',
#     '37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5'],
#    'url_key': 'nike-sportswear-react-55-se-baskets-basses-blackwhite-ni112o0aj-q12',
#    'media': [{'path': 'NI/11/2O/0A/JQ/12/NI112O0AJ-Q12@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI112O0AJ-C11',
#    'name': 'REACT 55 SE - Baskets basses - pumice/metalic silver/total orange/summit white/black',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '74,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-react-55-se-baskets-basses-ni112o0aj-c11',
#    'media': [{'path': 'NI/11/2O/0A/JC/11/NI112O0AJ-C11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA222F001-802',
#    'name': 'Polo - black',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '66,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-crocodile-caiman-polo-noir-la222f001-802',
#    'media': [{'path': 'LA/22/2F/00/18/02/LA222F001-802@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2F/00/18/02/LA222F001-802@16.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GS122S0BP-K11',
#    'name': 'GRAPHIC 12 SLIM R SW L\\S - Sweatshirt - sartho blue',
#    'price': {'original': '89,95\xa0€',
#     'promotional': '71,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'g-star-graphic-12-slim-r-sw-ls-sweatshirt-sartho-blue-gs122s0bp-k11',
#    'media': [{'path': 'GS/12/2S/0B/PK/11/GS122S0BP-K11@16.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'GS/12/2S/0B/PK/11/GS122S0BP-K11@17.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'G-Star',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222S02L-K11',
#    'name': 'Sweatshirt - blue',
#    'price': {'original': '129,95\xa0€',
#     'promotional': '64,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL', '4XL'],
#    'url_key': 'lacoste-sweatshirt-blue-la222s02l-k11',
#    'media': [{'path': 'LA/22/2S/02/LK/11/LA222S02L-K11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2S/02/LK/11/LA222S02L-K11@14.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VC122P00V-Q11',
#    'name': 'Polo - nero',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '86,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', '3XL'],
#    'url_key': 'versace-collection-polo-nero-vc122p00v-q11',
#    'media': [{'path': 'VC/12/2P/00/VQ/11/VC122P00V-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VC/12/2P/00/VQ/11/VC122P00V-Q11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Versace Collection',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222F001-503',
#    'name': 'Polo - ruisseau',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '56,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-crocodil-caiman-polo-bleu-la222f001-503',
#    'media': [{'path': 'LA/22/2F/00/15/03/LA222F001-503@18.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2F/00/15/03/LA222F001-503@19.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE222G06P-Q11',
#    'name': '510 SKINNY FIT - Jeans Skinny - stylo',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '54,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['26x30',
#     '28x30',
#     '28x32',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '34x30',
#     '34x32',
#     '34x34',
#     '36x30',
#     '36x32',
#     '36x34'],
#    'url_key': 'levisr-510-skinny-fit-jeans-skinny-stylo-le222g06p-q11',
#    'media': [{'path': 'LE/22/2G/06/PQ/11/LE222G06P-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LE/22/2G/06/PQ/11/LE222G06P-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TH342D00U-C11',
#    'name': 'EASY - T-shirt imprimé - grey heather',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '16,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'the-north-face-easy-t-shirt-imprime-grey-heather-th342d00u-c11',
#    'media': [{'path': 'TH/34/2D/00/UC/11/TH342D00U-C11@13.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TH/34/2D/00/UC/11/TH342D00U-C11@15.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'The North Face',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O08P-Q11',
#    'name': 'P-6000 - Baskets basses - black',
#    'price': {'original': '109,95\xa0€',
#     'promotional': '54,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5',
#     '38',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-p-6000-baskets-basses-black-ni112o08p-q11',
#    'media': [{'path': 'NI/11/2O/08/PQ/11/NI112O08P-Q11@12.2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA222D01Z-C11',
#    'name': 'T-shirt basique - paladium chine',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '27,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-t-shirt-basique-gris-la222d01z-c11',
#    'media': [{'path': 'LA/22/2D/01/ZC/11/LA222D01Z-C11@15.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2D/01/ZC/11/LA222D01Z-C11@16.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TOB22G00Z-K11',
#    'name': 'SLIM SCANTON BELB - Jean slim - berry light blue',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '49,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x30',
#     '28x32',
#     '28x34',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x32',
#     '31x34',
#     '31x36',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x32',
#     '33x34',
#     '34x30',
#     '34x32',
#     '34x34',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '38x30',
#     '38x34',
#     '38x36'],
#    'url_key': 'tommy-jeans-slim-scanton-belb-jean-slim-berry-light-blue-tob22g00z-k11',
#    'media': [{'path': 'TO/B2/2G/00/ZK/11/TOB22G00Z-K11@12.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/B2/2G/00/ZK/11/TOB22G00Z-K11@13.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Jeans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ED322O026-A11',
#    'name': 'DREAMERS  - T-shirt imprimé - white',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '21,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'edwin-dreamers-t-shirt-imprime-white-ed322o026-a11',
#    'media': [{'path': 'ED/32/2O/02/6A/11/ED322O026-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ED/32/2O/02/6A/11/ED322O026-A11@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Edwin',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'VA222O03F-C12',
#    'name': 'LEFT CHEST LOGO TEE - T-shirt basique - athletic heather',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '14,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'XL', 'XXL'],
#    'url_key': 'vans-left-chest-logo-tee-t-shirt-basique-va222o03f-c12',
#    'media': [{'path': 'VA/22/2O/03/FC/12/VA222O03F-C12@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'VA/22/2O/03/FC/12/VA222O03F-C12@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Vans',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'H0422O056-A11',
#    'name': '5 PACK CREW  - T-shirt imprimé - white/grey/red/navy texture/black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '42,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'hollister-co-5-pack-crew-t-shirt-imprime-whitegreyrednavy-textureblack-h0422o056-a11',
#    'media': [{'path': 'H0/42/2O/05/6A/11/H0422O056-A11@8.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'H0/42/2O/05/6A/11/H0422O056-A11@10.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Hollister Co.',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GS122E07J-C12',
#    'name': 'Pantalon cargo - grey',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27x30',
#     '27x32',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x30',
#     '31x32',
#     '31x34',
#     '31x36',
#     '31x38',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '33x38',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '34x38',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '36x38',
#     '38x30',
#     '38x32',
#     '38x34',
#     '38x36',
#     '38x38',
#     '40x32',
#     '40x34',
#     '40x36'],
#    'url_key': 'g-star-rovic-zip-3d-tapered-pantalon-cargo-gs122e07j-c12',
#    'media': [{'path': 'GS/12/2E/07/JC/12/GS122E07J-C12@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'GS/12/2E/07/JC/12/GS122E07J-C12@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'G-Star',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'S2315O000-N12',
#    'name': 'JAZZ ORIGINAL VINTAGE - Baskets basses - olive/black',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '75,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['40', '40.5', '41', '42', '42.5', '43', '44.5', '45', '46'],
#    'url_key': 'saucony-jazz-original-vintage-baskets-basses-s2315o000-n12',
#    'media': [{'path': 'S2/31/5O/00/0N/12/S2315O000-N12@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Saucony',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO122O078-K11',
#    'name': 'LOGO TEE - T-shirt imprimé - blue',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '31,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'tommy-hilfiger-logo-tee-t-shirt-imprime-to122o078-k11',
#    'media': [{'path': 'TO/12/2O/07/8K/11/TO122O078-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/12/2O/07/8K/11/TO122O078-K11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO122S06Q-C11',
#    'name': 'LOGO HOODY - Sweat à capuche - grey',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '79,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'tommy-hilfiger-logo-hoody-sweatshirt-to122s06q-c11',
#    'media': [{'path': 'TO/12/2S/06/QC/11/TO122S06Q-C11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'TO/12/2S/06/QC/11/TO122S06Q-C11@3.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'BRH22Q01A-A11',
#    'name': 'SEYMOUR - Pullover - midnight navy/ slate grey/ vintage white/ winter lime',
#    'price': {'original': '26,95\xa0€',
#     'promotional': '21,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL'],
#    'url_key': 'brave-soul-seymour-pullover-midnight-navy-slate-grey-vintage-white-winter-lime-brh22q01a-a11',
#    'media': [{'path': 'BR/H2/2Q/01/AA/11/BRH22Q01A-A11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'BR/H2/2Q/01/AA/11/BRH22Q01A-A11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Brave Soul',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O093-H11',
#    'name': 'SIGNAL D/MS/X - Baskets basses - guava ice/light aqua/hyper crimson/blue hero/cedar/black',
#    'price': {'original': '124,95\xa0€',
#     'promotional': '61,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-signal-dmsx-baskets-basses-ni112o093-h11',
#    'media': [{'path': 'NI/11/2O/09/3H/11/NI112O093-H11@9.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'NI/11/2O/09/3H/11/NI112O093-H11@19.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'H0422O05M-A11',
#    'name': 'RAGLAN - T-shirt imprimé - white',
#    'price': {'original': '33,95\xa0€',
#     'promotional': '16,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'hollister-co-raglan-t-shirt-imprime-white-h0422o05m-a11',
#    'media': [{'path': 'H0/42/2O/05/MA/11/H0422O05M-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'H0/42/2O/05/MA/11/H0422O05M-A11@9.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Hollister Co.',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'YO122SA39-Q11',
#    'name': 'veste en sweat zippée - black/white',
#    'price': {'original': '31,99\xa0€',
#     'promotional': '22,39\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XXS', 'XS', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'your-turn-sweat-zippe-black-white-yo122sa39-q11',
#    'media': [{'path': 'YO/12/2S/A3/9Q/11/YO122SA39-Q11@12.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'YO/12/2S/A3/9Q/11/YO122SA39-Q11@13.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'YOURTURN',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'UR622E01B-Q11',
#    'name': 'JOGGING PANT - Pantalon cargo - black',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,99\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'urban-classics-jogging-pant-pantalon-cargo-ur622e01b-q11',
#    'media': [{'path': 'UR/62/2E/01/BQ/11/UR622E01B-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'UR/62/2E/01/BQ/11/UR622E01B-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Urban Classics',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI112O08W-K11',
#    'name': 'AIR MAX 200 - Baskets basses - royal pulse/oil grey/light aqua/ember glow/chrome yellow/white',
#    'price': {'original': '119,95\xa0€',
#     'promotional': '59,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '45.5',
#     '46',
#     '47',
#     '47.5',
#     '48.5',
#     '49.5'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-royal-pulseoil-greylight-aquaember-glowchrome-yellowwhite-ni112o08w-k11',
#    'media': [{'path': 'NI/11/2O/08/WK/11/NI112O08W-K11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI122O0B5-Q12',
#    'name': 'REPEAT TEE - T-shirt imprimé - black/metallic gold',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL'],
#    'url_key': 'nike-sportswear-repeat-tee-t-shirt-imprime-ni122o0b5-q12',
#    'media': [{'path': 'NI/12/2O/0B/5Q/12/NI122O0B5-Q12@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'NI/12/2O/0B/5Q/12/NI122O0B5-Q12@7.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222P00Q-A11',
#    'name': 'Polo - white',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '66,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', 'XXL', '3XL'],
#    'url_key': 'lacoste-slim-fit-polo-white-la222p00q-a11',
#    'media': [{'path': 'LA/22/2P/00/QA/11/LA222P00Q-A11@14.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2P/00/QA/11/LA222P00Q-A11@15.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GS122G08T-K16',
#    'name': 'REVEND SKINNY - Jeans Skinny - black pintt stretch denim',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '49,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['25x28',
#     '25x30',
#     '25x32',
#     '26x30',
#     '26x32',
#     '26x34',
#     '27x28',
#     '27x30',
#     '27x32',
#     '27x34',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x28',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x28',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x30',
#     '31x32',
#     '31x34',
#     '31x36',
#     '31x38',
#     '32x28',
#     '32x32',
#     '32x34',
#     '32x36',
#     '32x38',
#     '33x34',
#     '33x36',
#     '33x38',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '34x38',
#     '35x30',
#     '35x32',
#     '35x34',
#     '35x36',
#     '35x38',
#     '36x28',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '36x38',
#     '38x30',
#     '38x32',
#     '38x34',
#     '38x36',
#     '38x38',
#     '40x32',
#     '40x34',
#     '40x36',
#     '40x38'],
#    'url_key': 'g-star-revend-super-slim-jean-slim-gs122g08t-k16',
#    'media': [{'path': 'GS/12/2G/08/TK/16/GS122G08T-K16@14.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'GS/12/2G/08/TK/16/GS122G08T-K16@15.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'G-Star',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'PU115O05D-K11',
#    'name': 'AXIS - Baskets basses - black/blue turquoise/castlerock/silver/high rise',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['37.5',
#     '38.5',
#     '39',
#     '40',
#     '40.5',
#     '41',
#     '42',
#     '42.5',
#     '43',
#     '44',
#     '44.5',
#     '45',
#     '47'],
#    'url_key': 'puma-axis-baskets-basses-pu115o05d-k11',
#    'media': [{'path': 'PU/11/5O/05/DK/11/PU115O05D-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Puma',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GS122G0C8-C11',
#    'name': '3301 SLIM - Jean slim - anthrazit',
#    'price': {'original': '129,95\xa0€',
#     'promotional': '70,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['24x32',
#     '24x34',
#     '25x28',
#     '25x30',
#     '25x32',
#     '25x34',
#     '26x30',
#     '26x32',
#     '26x34',
#     '27x30',
#     '27x32',
#     '27x34',
#     '28x28',
#     '28x30',
#     '28x32',
#     '28x34',
#     '29x28',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x28',
#     '30x30',
#     '30x32',
#     '30x34',
#     '30x36',
#     '31x30',
#     '31x32',
#     '31x34',
#     '31x36',
#     '31x38',
#     '32x28',
#     '32x30',
#     '32x32',
#     '32x34',
#     '32x36',
#     '32x38',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '33x38',
#     '34x30',
#     '34x32',
#     '34x34',
#     '34x36',
#     '34x38',
#     '35x30',
#     '35x32',
#     '35x34',
#     '35x36',
#     '35x38',
#     '36x30',
#     '36x32',
#     '36x34',
#     '36x36',
#     '36x38',
#     '38x30',
#     '38x32',
#     '38x34',
#     '38x36',
#     '38x38',
#     '40x32',
#     '40x34',
#     '40x36',
#     '40x38'],
#    'url_key': 'g-star-jean-slim-loomer-grey-stretch-denim-gs122g0c8-c11',
#    'media': [{'path': 'GS/12/2G/0C/8C/11/GS122G0C8-C11@17.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'GS/12/2G/0C/8C/11/GS122G0C8-C11@13.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'G-Star',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -45%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'BRH22G02E-C11',
#    'name': 'FLETCHCORD - Jeans Skinny - charcoal',
#    'price': {'original': '39,95\xa0€',
#     'promotional': '19,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x32',
#     '28x34',
#     '30x32',
#     '30x34',
#     '32x32',
#     '32x34',
#     '34x32',
#     '34x34',
#     '36x32',
#     '36x34'],
#    'url_key': 'brave-soul-jean-slim-charcoal-brh22g02e-c11',
#    'media': [{'path': 'BR/H2/2G/02/EC/11/BRH22G02E-C11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'BR/H2/2G/02/EC/11/BRH22G02E-C11@8.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Brave Soul',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222P045-K11',
#    'name': 'NORMAL FIT PH9396 - Polo - inkwell/black-navy blue',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '69,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['XS', 'S', 'M', 'L', 'XL', '3XL'],
#    'url_key': 'lacoste-normal-fit-ph9396-t-shirt-a-manches-longues-la222p045-k11',
#    'media': [{'path': 'LA/22/2P/04/5K/11/LA222P045-K11@20.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2P/04/5K/11/LA222P045-K11@15.1.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'OS322E04A-C11',
#    'name': 'ONSMARK PANT - Pantalon classique - medium grey melange',
#    'price': {'original': '39,99\xa0€',
#     'promotional': '33,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28x30',
#     '28x32',
#     '28x34',
#     '29x30',
#     '29x32',
#     '29x34',
#     '30x30',
#     '30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x30',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '34x32',
#     '34x34',
#     '36x32',
#     '36x34'],
#    'url_key': 'only-and-sons-onsmark-pant-pantalon-classique-os322e04a-c11',
#    'media': [{'path': 'OS/32/2E/04/AC/11/OS322E04A-C11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'OS/32/2E/04/AC/11/OS322E04A-C11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Only & Sons',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'ES122E033-K12',
#    'name': 'Chino - blue',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['30x32',
#     '30x34',
#     '31x30',
#     '31x32',
#     '31x34',
#     '32x32',
#     '32x34',
#     '33x30',
#     '33x32',
#     '33x34',
#     '33x36',
#     '34x32',
#     '34x34',
#     '36x32',
#     '36x34'],
#    'url_key': 'esprit-chino-blue-es122e033-k12',
#    'media': [{'path': 'ES/12/2E/03/3K/12/ES122E033-K12@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'ES/12/2E/03/3K/12/ES122E033-K12@6.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Esprit',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LA222T00O-Q11',
#    'name': 'Veste mi-saison - black/wheelwright',
#    'price': {'original': '259,95\xa0€',
#     'promotional': '168,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['44', '46', '48', '50', '52', '54', '56'],
#    'url_key': 'lacoste-veste-mi-saison-blackwheelwright-la222t00o-q11',
#    'media': [{'path': 'LA/22/2T/00/OQ/11/LA222T00O-Q11@10.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False},
#     {'path': 'LA/22/2T/00/OQ/11/LA222T00O-Q11@11.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'HU752M00S-O11',
#    'name': 'STAND - Montre - brown',
#    'price': {'original': '114,95\xa0€',
#     'promotional': '91,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['One Size'],
#    'url_key': 'hugo-stand-montre-hu752m00s-o11',
#    'media': [{'path': 'HU/75/2M/00/SO/11/HU752M00S-O11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True},
#     {'path': 'HU/75/2M/00/SO/11/HU752M00S-O11@5.jpg',
#      'role': 'HOVER',
#      'packet_shot': False}],
#    'brand_name': 'HUGO',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'accessoires',
#    'delivery_promises': []},
# ...
#   {'key': 'discounts',
#    'label': 'Réduction',
#    'url_key': 'discount',
#    'kind': 'values',
#    'values': [{'key': 'DISCOUNT0', 'label': 'jusqu’à -20 %'},
#     {'key': 'DISCOUNT1', 'label': '-20 %'},
#     {'key': 'DISCOUNT2', 'label': '-30 %'},
#     {'key': 'DISCOUNT3', 'label': '-40 %'},
#     {'key': 'DISCOUNT4', 'label': '-50 %'},
#     {'key': 'DISCOUNT5', 'label': '-60 % et plus'}]},
#   {'key': 'upper_materials',
#    'label': 'Matière',
#    'url_key': 'upper_material',
#    'kind': 'values',
#    'values': [{'key': 'OTHER', 'label': 'Autres matières'},
#     {'key': 'CASHMERE', 'label': 'Cachemire'},
#     {'key': 'CAOUTCHOUC', 'label': 'Caoutchouc'},
#     {'key': 'COTTON', 'label': 'Coton'},
#     {'key': 'CROCHETED', 'label': 'Crocheté'},
#     {'key': 'LEATHER', 'label': 'Cuir'},
#     {'key': 'CORD', 'label': 'Côtelé'},
#     {'key': 'DENIM', 'label': 'Denim'},
#     {'key': 'FLANELETTE', 'label': 'Flanelle chaude'},
#     {'key': 'HARDSHELL', 'label': 'Hardshell'},
#     {'key': 'IMITATION_LEATHER', 'label': 'Imitation cuir'},
#     {'key': 'JERSEY', 'label': 'Jersey'},
#     {'key': 'WOOL', 'label': 'Laine'},
#     {'key': 'LINEN', 'label': 'Lin'},
#     {'key': 'MESH', 'label': 'Mesh'},
#     {'key': 'FLEECE', 'label': 'Polaire'},
#     {'key': 'POLYESTER', 'label': 'Polyester'},
#     {'key': 'SATIN', 'label': 'Satin'},
#     {'key': 'SOFTSHELL', 'label': 'Softshell'},
#     {'key': 'SILK', 'label': 'Soie'},
#     {'key': 'RIB', 'label': 'Strié'},
#     {'key': 'SWEAT', 'label': 'Sweat'},
#     {'key': 'SYNTHETIC', 'label': 'Synthétique'},
#     {'key': 'TEXTILE', 'label': 'Textile'},
#     {'key': 'BRAIDED', 'label': 'tressé'},
#     {'key': 'VARNISH', 'label': 'Verni'},
#     {'key': 'VISCOSE', 'label': 'Viscose'}]},
#   {'key': 'sustainable',
#    'label': 'Éco-responsable',
#    'url_key': 'sustainable',
#    'kind': 'single_value',
#    'values': [{'key': 'true', 'label': 'Éco-responsable'}],
#    'group_id': 'sustainable'},
#   {'key': 'multipack',
#    'label': 'Nombre de multi-packs',
#    'url_key': 'multipack',
#    'kind': 'values',
#    'values': [{'key': '2', 'label': '2 packs'},
#     {'key': '3', 'label': '3 packs'},
#     {'key': '4', 'label': '4 packs'},
#     {'key': '5', 'label': '5 packs'},
#     {'key': '6', 'label': '6 packs'},
#     {'key': '7', 'label': '7 packs'},
#     {'key': '8', 'label': '8 packs'},
#     {'key': '9', 'label': '9 packs'},
#     {'key': '10', 'label': '10 packs'},
#     {'key': '12', 'label': '12 packs'}]},
#   {'key': 'patterns',
#    'label': 'Motif',
#    'url_key': 'pattern',
#    'kind': 'values',
#    'values': [{'key': 'CAMOUFLAGE', 'label': 'camouflage'},
#     {'key': 'STRIPED', 'label': 'carreaux'},
#     {'key': 'HERRING_BONE', 'label': 'chevrons'},
#     {'key': 'FLECKED', 'label': 'chiné'},
#     {'key': 'PLAIN', 'label': 'couleur unie'},
#     {'key': 'GRADIENT', 'label': 'dégradé'},
#     {'key': 'BURNOUT', 'label': 'dévoré'},
#     {'key': 'PINSTRIPE', 'label': 'fines rayures'},
#     {'key': 'POLKA_DOT', 'label': 'floral'},
#     {'key': 'PRINT', 'label': 'imprimé'},
#     {'key': 'ANIMAL_PRINT', 'label': 'imprimé animal'},
#     {'key': 'PHOTO_PRINT', 'label': 'imprimé photo'},
#     {'key': 'COLORED', 'label': 'multicolore'},
#     {'key': 'PAISLEY', 'label': 'Paisley/cachemire'},
#     {'key': 'CHECKERED', 'label': 'rayures'},
#     {'key': 'FLORAL', 'label': 'à pois'}]},
#   {'key': 'occasions',
#    'label': 'Occasion',
#    'url_key': 'occasion',
#    'kind': 'values',
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'lengths',
#    'label': 'Longueur',
#    'url_key': 'length',
#    'kind': 'values',
#    'values': [{'key': '26', 'label': '26'},
#     {'key': '28', 'label': '28'},
#     {'key': '29', 'label': '29'},
#     {'key': '3/4', 'label': '3/4'},
#     {'key': '30', 'label': '30'},
#     {'key': '31', 'label': '31'},
#     {'key': '32', 'label': '32'},
#     {'key': '33', 'label': '33'},
#     {'key': '34', 'label': '34'},
#     {'key': '35', 'label': '35'},
#     {'key': '36', 'label': '36'},
#     {'key': '38', 'label': '38'},
#     {'key': '40', 'label': '40'},
#     {'key': '7/8', 'label': '7/8'},
#     {'key': 'courte', 'label': 'courte'},
#     {'key': 'extra courte', 'label': 'extra courte'},
#     {'key': 'extra longue', 'label': 'extra longue'},
#     {'key': "Jusqu'aux genoux", 'label': "Jusqu'aux genoux"},
#     {'key': 'longue', 'label': 'longue'},
#     {'key': 'Longueur mi-cuisse', 'label': 'Longueur mi-cuisse'},
#     {'key': 'Longueur midi', 'label': 'Longueur midi'},
#     {'key': 'Moyenne', 'label': 'Moyenne'},
#     {'key': 'normale', 'label': 'normale'},
#     {'key': 'socquettes', 'label': 'socquettes'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'PLUS_SIZE', 'label': 'Grandes tailles'},
#     {'key': 'TALL', 'label': 'Grande'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_fresh_days_2019_49', 'label': '-20% EXTRA'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]}],
#  'total_article_count': 55982,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9191',
#    'url_key': 'promo-homme',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-homme/',
#    'children': [{'label': 'Vêtements',
#      'id': '9205',
#      'url_key': 'promo-mode-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-homme/',
#      'children': [],
#      'article_count': 38434},
#     {'label': 'Chaussures',
#      'id': '9192',
#      'url_key': 'promo-chaussures-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-homme/',
#      'children': [],
#      'article_count': 12118},
#     {'label': 'Sport',
#      'id': '13690',
#      'url_key': 'promo-sport-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-homme/',
#      'children': [],
#      'article_count': 7883},
#     {'label': 'Accessoires',
#      'id': '9222',
#      'url_key': 'promo-accessoires-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-homme/',
#      'children': [],
#      'article_count': 5090},
#     {'label': 'Luxe',
#      'id': '13825',
#      'url_key': 'promo-luxe-homme',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-homme/',
#      'children': [],
#      'article_count': 4906},
#     {'label': 'Beauté',
#      'id': '13865',
#      'url_key': 'beaute-homme-soins-promo',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/beaute-homme-soins-promo/',
#      'children': [],
#      'article_count': 174}],
#    'article_count': 55967}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Homme',
#      'url_key': 'homme',
#      'full_url': '/homme/'},
#     {'label': 'Promos',
#      'url_key': 'promo-homme',
#      'full_url': '/promo-homme/'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-homme',
#       'url_key': 'promo-homme',
#       'label': 'Promos',
#       'seo_label': 'Promotions homme',
#       'reset_url': '/',
#       'id': '9191'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-homme/',
#   'reset_url': '/promo-homme/',
#   'app_url': '?urlKey=promo-homme&order=popularity&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-homme',
#     'url_key': 'promo-homme',
#     'label': 'Promos',
#     'seo_label': 'Promotions homme',
#     'reset_url': '/',
#     'id': '9191'}]},
#  'selectedFilters': {'categories': ['promo-homme']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': 'Offrez-vous les tendances de la mode actuelle à prix réduits. Des costumes élégants aux baskets décontractées et lunettes de soleil tendances de marques célèbres, les articles en promo pour homme vous attendent',
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/7b593a52-7063-4143-ad31-f7af69276277/fd9498bc-dcb6-4ea9-9e13-926eb8931695/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=eb7f9181-d542-4d64-89f1-709079e25af9&timeUnit=null&timeUnitCount=null&uuid=d9e0ef99-91ec-4be2-b857-dbdba95c59b8&bid=null&requestId=aa965f7b-5479-4cf9-b30f-7166b86fcc2e&s=550EC9F759313A1CA2BB0E0D852A1B67'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/38e70c9fb0f041ea876b0cc28aa5c60d/2810e5951f4b4de2bbb9fd5849bb5925.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/555/960/819/750/spp-media-p1/49d18e553a76400592b0de76b11a4da8/ba63237dec8847c6bf839204ea72c349.jpeg',
#      'image_width': None}],
#    'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9',
#    'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277',
#    'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#    'campaign_source_id': 'RQsmB4tXTAC',
#    'text_fields': {'cta': "J'en profite",
#     'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 17/12/2019 à 23h59 sur les articles soldés et les prix minis, à partir de 90€ d'achat.",
#     'voucher_code': 'STAYFRESH',
#     'title': "JUSQU'À -50% ET -20% EXTRA",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': 'Juste à temps pour Noël ⏰',
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': '8M7HTNBdo3-ueWR6',
#       'price': 0.012448337749409722,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'RQsmB4tXTAC',
#       'request_id': 'aa965f7b-5479-4cf9-b30f-7166b86fcc2e',
#       'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277',
#       'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'nVgMP-U9TsC',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '8M7HTNBdo3-ueWR6',
#        'price': 0.012448337749409722,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'aa965f7b-5479-4cf9-b30f-7166b86fcc2e',
#        'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277'},
#       'dimension74': {'adId': 'nVgMP-U9TsC'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'nVgMP-U9TsC',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': '8M7HTNBdo3-ueWR6',
#        'price': 0.012448337749409722,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'aa965f7b-5479-4cf9-b30f-7166b86fcc2e',
#        'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277'},
#       'dimension74': {'adId': 'nVgMP-U9TsC'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/7b593a52-7063-4143-ad31-f7af69276277/fd9498bc-dcb6-4ea9-9e13-926eb8931695/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=eb7f9181-d542-4d64-89f1-709079e25af9&timeUnit=null&timeUnitCount=null&uuid=afc8f57f-7ae9-4ef2-817a-c24ce7e9c7a8&bid=12&requestId=aa965f7b-5479-4cf9-b30f-7166b86fcc2e&s=6D69D4BD60D70A6FFE17010EB7A5147C'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': '8M7HTNBdo3-ueWR6',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277',
#      'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'shop_slot_id': 'catalog',
#      'creative_id': 'eb7f9181-d542-4d64-89f1-709079e25af9',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'adId': 'nVgMP-U9TsC',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': '8M7HTNBdo3-ueWR6',
#      'price': 0.012448337749409722,
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'request_id': 'aa965f7b-5479-4cf9-b30f-7166b86fcc2e',
#      'campaign_id': '7b593a52-7063-4143-ad31-f7af69276277'}},
#    'click_url': 'https://www.zalando.fr/promo-homme/?camp=fr_aw19_fresh_days_2019_49&sale=true'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': None,
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
# Flatten the data and store it in an empty object variable:

flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])

flattened_data1
# Out:
#               sku                                               name  \
# 0   TOB22O01B-Q11  ORIGINAL SLIM FIT - T-shirt à manches longues ...
# 1   TOB22O04X-Q11                BADGE TEE - T-shirt basique - black
# 2   VA215B000-Q12            OLD SKOOL - Chaussures de skate - black
# 3   PI922EA0O-K11                                  Chino - dark blue
# 4   NI112O0AY-Q11  AIR MAX 97  - Baskets basses - anthracite/volt...
# ..            ...                                                ...
# 79  NI122F01J-Q11      CLUB - Pantalon de survêtement - schwarz/weiß
# 80  NI122E06F-Q11         METALLIC - Pantalon de survêtement - black
# 81  S3722T01K-Q11                     ALASKA - Veste d'hiver - black
# 82  TOB22S032-Q11             BADGE HOODIE - Sweat à capuche - black
# 83  NI112O08P-H11  P-6000 - Baskets basses - total orange/black/a...
#
#                                                 sizes  \
# 0                              [XS, S, M, L, XL, XXL]
# 1                              [XS, S, M, L, XL, XXL]
# 2   [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# 3                            [29, 30, 31, 32, 33, 34]
# 4   [38.5, 39, 40, 40.5, 41, 42, 42.5, 43, 44, 44....
# ..                                                ...
# 79                        [XS, S, M, L, XL, XXL, 3XL]
# 80                             [XS, S, M, L, XL, XXL]
# 81                                  [XS, S, M, L, XL]
# 82                             [XS, S, M, L, XL, XXL]
# 83  [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
#
#                                               url_key  \
# 0   tommy-jeans-original-t-shirt-a-manches-longues...
# 1   tommy-jeans-badge-tee-t-shirt-basique-tob22o04...
# 2         vans-old-skool-baskets-basses-va215b000-q12
# 3              pier-one-chino-dark-blue-pi922ea0o-k11
# 4   nike-sportswear-air-max-97-baskets-basses-anth...
# ..                                                ...
# 79  nike-sportswear-pantalon-de-survetement-schwar...
# 80  nike-sportswear-metallic-pantalon-de-surveteme...
# 81     schott-alaska-veste-dhiver-black-s3722t01k-q11
# 82         tommy-jeans-badge-sweatshirt-tob22s032-q11
# 83  nike-sportswear-p-6000-baskets-basses-ni112o08...
#
#                                                 media       brand_name  \
# 0   [{'path': 'TO/B2/2O/01/BQ/11/TOB22O01B-Q11@8.j...      Tommy Jeans
# 1   [{'path': 'TO/B2/2O/04/XQ/11/TOB22O04X-Q11@9.j...      Tommy Jeans
# 2   [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12....             Vans
# 3   [{'path': 'PI/92/2E/A0/OK/11/PI922EA0O-K11@10....         Pier One
# 4   [{'path': 'NI/11/2O/0A/YQ/11/NI112O0AY-Q11@5.j...  Nike Sportswear
# ..                                                ...              ...
# 79  [{'path': 'NI/12/2F/01/JQ/11/NI122F01J-Q11@10....  Nike Sportswear
# 80  [{'path': 'NI/12/2E/06/FQ/11/NI122E06F-Q11@4.j...  Nike Sportswear
# 81  [{'path': 'S3/72/2T/01/KQ/11/S3722T01K-Q11@14....           Schott
# 82  [{'path': 'TO/B2/2S/03/2Q/11/TOB22S032-Q11@4.j...      Tommy Jeans
# 83  [{'path': 'NI/11/2O/08/PH/11/NI112O08P-H11@11....  Nike Sportswear
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 82  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 83  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        34,95 €           27,95 €
# 1                 []        39,95 €           19,95 €
# 2                 []        74,95 €           67,45 €
# 3                 []        29,99 €           16,49 €
# 4                 []       169,95 €          101,95 €
# ..               ...            ...               ...
# 79                []        24,95 €           21,15 €
# 80                []        49,95 €           32,45 €
# 81                []       164,95 €          139,95 €
# 82                []        99,95 €           79,95 €
# 83                []       109,95 €           54,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                        True                                False
# 80                        True                                False
# 81                       False                                False
# 82                       False                                False
# 83                        True                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                    True
# 80                                    True
# 81                                   False
# 82                                   False
# 83                                    True
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#                                               outfits
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'id': 'nmnnhTu7SCu', 'url_key': '/outfits/nm...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
# [84 rows x 18 columns]

# %%
# Find out the total page count in the 1st page data.
total_pages=results['pagination']['page_count']

# %%
# Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.

df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=popularity'
    #response = requests.get(url)
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1, sort=False)

df
# Out:
#                                                             name  \
# sku
# TOB22O01B-Q11  ORIGINAL SLIM FIT - T-shirt à manches longues ...
# TOB22O04X-Q11                BADGE TEE - T-shirt basique - black
# VA215B000-Q12            OLD SKOOL - Chaussures de skate - black
# PI922EA0O-K11                                  Chino - dark blue
# NI112O0AY-Q11  AIR MAX 97  - Baskets basses - anthracite/volt...
# ...                                                          ...
# N1244D073-A11        FUTURE FEMME - Chaussettes de sport - black
# AS144D00H-Q11  CUSHIONING 2 PACK - Socquettes - performance b...
# GOD44E00H-C11                 Chaussettes de sport - white/black
# RE544D026-L11   OST CREW SOCK - Chaussettes de sport - turquoise
# N1244D06Z-K11  FC BARCELONA - Chaussettes hautes - deep royal...
#
#                                                            sizes  \
# sku
# TOB22O01B-Q11                             [XS, S, M, L, XL, XXL]
# TOB22O04X-Q11                             [XS, S, M, L, XL, XXL]
# VA215B000-Q12  [34.5, 35, 36, 36.5, 37, 38, 38.5, 39, 40, 40....
# PI922EA0O-K11                           [29, 30, 31, 32, 33, 34]
# NI112O0AY-Q11  [38.5, 39, 40, 40.5, 41, 42, 42.5, 43, 44, 44....
# ...                                                          ...
# N1244D073-A11                                            [46-48]
# AS144D00H-Q11                                            [35-38]
# GOD44E00H-C11                                            [38/40]
# RE544D026-L11                                            [43-45]
# N1244D06Z-K11                                            [46-50]
#
#                                                          url_key  \
# sku
# TOB22O01B-Q11  tommy-jeans-original-t-shirt-a-manches-longues...
# TOB22O04X-Q11  tommy-jeans-badge-tee-t-shirt-basique-tob22o04...
# VA215B000-Q12        vans-old-skool-baskets-basses-va215b000-q12
# PI922EA0O-K11             pier-one-chino-dark-blue-pi922ea0o-k11
# NI112O0AY-Q11  nike-sportswear-air-max-97-baskets-basses-anth...
# ...                                                          ...
# N1244D073-A11  nike-performance-future-femme-chaussettes-de-s...
# AS144D00H-Q11  asics-cushioning-2-pack-chaussettes-de-sport-a...
# GOD44E00H-C11  gore-wear-chaussettes-de-sport-whiteblack-god4...
# RE544D026-L11  reebok-crew-sock-chaussettes-de-sport-turquois...
# N1244D06Z-K11  nike-performance-fc-barcelona-chaussettes-haut...
#
#                                                            media  \
# sku
# TOB22O01B-Q11  [{'path': 'TO/B2/2O/01/BQ/11/TOB22O01B-Q11@8.j...
# TOB22O04X-Q11  [{'path': 'TO/B2/2O/04/XQ/11/TOB22O04X-Q11@9.j...
# VA215B000-Q12  [{'path': 'VA/21/5B/00/0Q/12/VA215B000-Q12@12....
# PI922EA0O-K11  [{'path': 'PI/92/2E/A0/OK/11/PI922EA0O-K11@10....
# NI112O0AY-Q11  [{'path': 'NI/11/2O/0A/YQ/11/NI112O0AY-Q11@5.j...
# ...                                                          ...
# N1244D073-A11  [{'path': 'N1/24/4D/07/3A/11/N1244D073-A11@6.j...
# AS144D00H-Q11  [{'path': 'AS/14/4D/00/HQ/11/AS144D00H-Q11@4.j...
# GOD44E00H-C11  [{'path': 'GO/D4/4E/00/HC/11/GOD44E00H-C11@8.1...
# RE544D026-L11  [{'path': 'RE/54/4D/02/6L/11/RE544D026-L11@6.j...
# N1244D06Z-K11  [{'path': 'N1/24/4D/06/ZK/11/N1244D06Z-K11@5.j...
#
#                      brand_name  is_premium family_articles  \
# sku
# TOB22O01B-Q11       Tommy Jeans       False              []
# TOB22O04X-Q11       Tommy Jeans       False              []
# VA215B000-Q12              Vans       False              []
# PI922EA0O-K11          Pier One       False              []
# NI112O0AY-Q11   Nike Sportswear       False              []
# ...                         ...         ...             ...
# N1244D073-A11  Nike Performance       False              []
# AS144D00H-Q11             ASICS       False              []
# GOD44E00H-C11         Gore Wear       False              []
# RE544D026-L11            Reebok       False              []
# N1244D06Z-K11  Nike Performance       False              []
#
#                                                            flags  \
# sku
# TOB22O01B-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# TOB22O04X-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# VA215B000-Q12  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# PI922EA0O-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# NI112O0AY-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# ...                                                          ...
# N1244D073-A11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# AS144D00H-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# GOD44E00H-C11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# RE544D026-L11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# N1244D06Z-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
#
#               product_group delivery_promises price.original  \
# sku
# TOB22O01B-Q11      clothing                []        34,95 €
# TOB22O04X-Q11      clothing                []        39,95 €
# VA215B000-Q12          shoe                []        74,95 €
# PI922EA0O-K11      clothing                []        29,99 €
# NI112O0AY-Q11          shoe                []       169,95 €
# ...                     ...               ...            ...
# N1244D073-A11     underwear                []        13,95 €
# AS144D00H-Q11     underwear                []        11,95 €
# GOD44E00H-C11     underwear                []        19,95 €
# RE544D026-L11     underwear                []        14,95 €
# N1244D06Z-K11     underwear                []        17,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# TOB22O01B-Q11           27,95 €                       False
# TOB22O04X-Q11           19,95 €                       False
# VA215B000-Q12           67,45 €                       False
# PI922EA0O-K11           16,49 €                       False
# NI112O0AY-Q11          101,95 €                       False
# ...                         ...                         ...
# N1244D073-A11           12,55 €                       False
# AS144D00H-Q11           10,75 €                       False
# GOD44E00H-C11           15,95 €                       False
# RE544D026-L11           13,45 €                       False
# N1244D06Z-K11           16,15 €                       False
#
#                price.has_different_original_prices  \
# sku
# TOB22O01B-Q11                                False
# TOB22O04X-Q11                                False
# VA215B000-Q12                                False
# PI922EA0O-K11                                False
# NI112O0AY-Q11                                False
# ...                                            ...
# N1244D073-A11                                False
# AS144D00H-Q11                                False
# GOD44E00H-C11                                False
# RE544D026-L11                                False
# N1244D06Z-K11                                False
#
#                price.has_different_promotional_prices  \
# sku
# TOB22O01B-Q11                                   False
# TOB22O04X-Q11                                   False
# VA215B000-Q12                                   False
# PI922EA0O-K11                                   False
# NI112O0AY-Q11                                   False
# ...                                               ...
# N1244D073-A11                                   False
# AS144D00H-Q11                                   False
# GOD44E00H-C11                                   False
# RE544D026-L11                                   False
# N1244D06Z-K11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# TOB22O01B-Q11                                      False
# TOB22O04X-Q11                                      False
# VA215B000-Q12                                      False
# PI922EA0O-K11                                      False
# NI112O0AY-Q11                                      False
# ...                                                  ...
# N1244D073-A11                                      False
# AS144D00H-Q11                                      False
# GOD44E00H-C11                                      False
# RE544D026-L11                                      False
# N1244D06Z-K11                                      False
#
#                                                          outfits amount  \
# sku
# TOB22O01B-Q11                                                NaN    NaN
# TOB22O04X-Q11                                                NaN    NaN
# VA215B000-Q12  [{'id': 'nmnnhTu7SCu', 'url_key': '/outfits/nm...    NaN
# PI922EA0O-K11                                                NaN    NaN
# NI112O0AY-Q11                                                NaN    NaN
# ...                                                          ...    ...
# N1244D073-A11                                                NaN    NaN
# AS144D00H-Q11                                                NaN    NaN
# GOD44E00H-C11                                                NaN    NaN
# RE544D026-L11                                                NaN    NaN
# N1244D06Z-K11                                                NaN    NaN
#
#               price.base_price
# sku
# TOB22O01B-Q11              NaN
# TOB22O04X-Q11              NaN
# VA215B000-Q12              NaN
# PI922EA0O-K11              NaN
# NI112O0AY-Q11              NaN
# ...                        ...
# N1244D073-A11              NaN
# AS144D00H-Q11              NaN
# GOD44E00H-C11              NaN
# RE544D026-L11              NaN
# N1244D06Z-K11              NaN
#
# [55953 rows x 19 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# The trending brand.

df.brand_name.value_counts().index[0]
# Out:
# 'Pier One'

# %%
# The product(s) with the highest discount.

df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Pier One'

# %%
# The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

df['percentage_discount']=(df['discount_amount'].astype(float) / df['price.original'].astype(float)) * 100
df2=df.copy()

# %%
sum_percentage_discount=df2.groupby(['brand_name']).max().percentage_discount.sort_values(ascending=False)

# %%
sum_percentage_discount
# Out:
# brand_name
# Missoni                96.941720
# Theory                 82.512893
# Paul Smith             78.835123
# Belstaff               70.641853
# SOULSTAR               70.631645
#                          ...
# North Sails            10.005003
# Spyder                 10.002942
# Living Kitzbühel        0.000000
# La Sportiva             0.000000
# Schott Made in USA   -575.359600
# Name: percentage_discount, Length: 796, dtype: float64
