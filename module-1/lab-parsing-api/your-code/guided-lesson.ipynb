# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=84&sort=sale'

# %%
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0"}

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
# Your code


#Replaced the original info:
#response = requests.get(url)
# with this: 
response = requests.get(url, headers=headers)
results = response.json()
results
# Out:
# {'total_count': 25788,
#  'pagination': {'page_count': 307, 'current_page': 2, 'per_page': 84},
#  'sort': 'sale',
#  'articles': [{'sku': 'AD116D0MY-A11',
#    'name': 'YUNG-96 CHASM - Baskets basses - footwear white/crystal white',
#    'price': {'original': '79,95\xa0€',
#     'promotional': '51,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36',
#     '38',
#     '40',
#     '35 1/2',
#     '36 2/3',
#     '37 1/3',
#     '38 2/3',
#     '39 1/3'],
#    'url_key': 'adidas-originals-yung-96-chasm-baskets-basses-footwear-whitecrystal-white-ad116d0my-a11',
#    'media': [{'path': 'AD/11/6D/0M/YA/11/AD116D0MY-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D07G-A11',
#    'name': 'STAN SMITH CF I - Chaussures premiers pas - white/green',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '39,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19',
#     '20',
#     '21',
#     '22',
#     '23',
#     '24',
#     '25',
#     '26',
#     '27',
#     '23 1/2',
#     '25 1/2',
#     '26 1/2'],
#    'url_key': 'adidas-originals-stan-smith-cf-i-baskets-basses-whitegreen-ad116d07g-a11',
#    'media': [{'path': 'AD/11/6D/07/GA/11/AD116D07G-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D00X-A11',
#    'name': 'SUPERSTAR - Baskets basses - white/metallic silver',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-superstar-baskets-basses-white-metallic-silver-ad116d00x-a11',
#    'media': [{'path': 'AD/11/6D/00/XA/11/AD116D00X-A11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI113D08S-J11',
#    'name': 'Baskets basses - pink foam/white/metallic platinum',
#    'price': {'original': '139,95\xa0€',
#     'promotional': '97,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5'],
#    'url_key': 'nike-sportswear-baskets-basses-pink-foamwhitemetallic-platinum-ni113d08s-j11',
#    'media': [{'path': 'NI/11/3D/08/SJ/11/NI113D08S-J11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LE224G080-C11',
#    'name': 'SPLIT TEE - T-shirt à manches longues - grey heather',
#    'price': {'original': '24,95\xa0€',
#     'promotional': '14,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-split-tee-t-shirt-a-manches-longues-grey-heather-le224g080-c11',
#    'media': [{'path': 'LE/22/4G/08/0C/11/LE224G080-C11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D07D-A12',
#    'name': 'CORTEZ BASIC  - Baskets basses - white / varsity red',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '45,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-cortez-basic-baskets-basses-white--varsity-red-ni114d07d-a12',
#    'media': [{'path': 'NI/11/4D/07/DA/12/NI114D07D-A12@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224L00H-K11',
#    'name': "WINTER JACKET - Veste d'hiver - capitaine",
#    'price': {'original': '144,95\xa0€',
#     'promotional': '86,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '6a', '8a', '10a', '12a', '16a'],
#    'url_key': 'lacoste-winter-jacket-veste-dhiver-capitaine-la224l00h-k11',
#    'media': [{'path': 'LA/22/4L/00/HK/11/LA224L00H-K11@30.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI116D04M-Q11',
#    'name': 'COURT BOROUGH MID WINTERIZED  - Chaussures premiers pas - black/white',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-court-borough-mid-winterized-baskets-montantes-blackwhite-ni116d04m-q11',
#    'media': [{'path': 'NI/11/6D/04/MQ/11/NI116D04M-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GP024K05M-C11',
#    'name': 'BOYS ACTIVE ARCH  - Sweat à capuche - light heather grey',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '20,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4-5a', '6-7a', '8-9a', '10-11a', '12-13a'],
#    'url_key': 'gap-boys-active-arch-sweatshirt-gp024k05m-c11',
#    'media': [{'path': 'GP/02/4K/05/MC/11/GP024K05M-C11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE223G03U-M11',
#    'name': 'BATWING TEE - T-shirt à manches longues - tea tree pink',
#    'price': {'original': '21,95\xa0€',
#     'promotional': '18,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-batwing-tee-t-shirt-a-manches-longues-le223g03u-m11',
#    'media': [{'path': 'LE/22/3G/03/UM/11/LE223G03U-M11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GP024K05M-K11',
#    'name': 'BOYS ACTIVE ARCH  - Sweat à capuche - blue galaxy',
#    'price': {'original': '29,95\xa0€',
#     'promotional': '20,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4-5a', '6-7a', '8-9a', '10-11a', '12-13a'],
#    'url_key': 'gap-boys-active-arch-sweatshirt-gp024k05m-k11',
#    'media': [{'path': 'GP/02/4K/05/MK/11/GP024K05M-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'GAP',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD124G02X-A11',
#    'name': 'GRAPHIC TEE - T-shirt imprimé - white/multicolor',
#    'price': {'original': '22,95\xa0€',
#     'promotional': '13,75\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7-8a', '8-9a', '9-10a', '10-11a', '11-12a', '13-14a', '14-15a'],
#    'url_key': 'adidas-originals-graphic-tee-t-shirt-imprime-whitemulticolor-ad124g02x-a11',
#    'media': [{'path': 'AD/12/4G/02/XA/11/AD124G02X-A11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': '6MO26G00N-A11',
#    'name': 'MINIME - T-shirt à manches longues - optic white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '33,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '6-9m', '9-12m', '12-18m', '18-24m'],
#    'url_key': 'moschino-minime-t-shirt-a-manches-longues-optic-white-6mo26g00n-a11',
#    'media': [{'path': '6M/O2/6G/00/NA/11/6MO26G00N-A11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'MOSCHINO',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CJ223F06O-J11',
#    'name': 'GIRL DRESSY BABY - Robe de soirée - pink',
#    'price': {'original': '32,95\xa0€',
#     'promotional': '21,35\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3m', '6m', '9m', '12m', '18m'],
#    'url_key': 'carters-girl-dressy-baby-robe-de-soiree-pink-cj223f06o-j11',
#    'media': [{'path': 'CJ/22/3F/06/OJ/11/CJ223F06O-J11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Carter's",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0AV-A11',
#    'name': 'AIR MAX 200 - Baskets basses - white/black/bright crimson/university gold',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '41,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0av-a11',
#    'media': [{'path': 'NI/11/4D/0A/VA/11/NI114D0AV-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI116D04L-K11',
#    'name': 'COURT BOROUGH MID BOOT WINTERIZED - Chaussures de skate - blue void/blue stardust/coast/topaz mist/photo blue',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '38,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '28.5', '29.5', '30', '31.5', '32', '33.5', '34', '35'],
#    'url_key': 'nike-sportswear-court-borough-mid-boot-winterized-baskets-montantes-ni116d04l-k11',
#    'media': [{'path': 'NI/11/6D/04/LK/11/NI116D04L-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0O2-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/real pink',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '45,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitereal-pink-ad116d0o2-a11',
#    'media': [{'path': 'AD/11/6D/0O/2A/11/AD116D0O2-A11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI126G01H-G11',
#    'name': 'NIKE DRI FIT - T-shirt imprimé - habanero red',
#    'price': {'original': '17,95\xa0€',
#     'promotional': '9,00\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2-3a', '3-4a', '4-5a', '5-6a', '6-7a'],
#    'url_key': 'nike-sportswear-nike-dri-fit-t-shirt-de-sport-ni126g01h-g11',
#    'media': [{'path': 'NI/12/6G/01/HG/11/NI126G01H-G11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'QU124L020-Q11',
#    'name': 'BICHENO BLOOM YOUTH - Veste mi-saison - black',
#    'price': {'original': '129,99\xa0€',
#     'promotional': '64,99\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['8a', '9a', '12a', '14a', '16a'],
#    'url_key': 'quiksilver-bicheno-bloom-youth-veste-dhiver-black-qu124l020-q11',
#    'media': [{'path': 'QU/12/4L/02/0Q/11/QU124L020-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Quiksilver',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'LE223G03R-A11',
#    'name': 'LIGHT BRIGHT CROPPED - T-shirt imprimé - white',
#    'price': {'original': '19,95\xa0€',
#     'promotional': '11,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['10a', '12a', '14a', '16a'],
#    'url_key': 'levisr-light-bright-cropped-t-shirt-imprime-white-le223g03r-a11',
#    'media': [{'path': 'LE/22/3G/03/RA/11/LE223G03R-A11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': "Levi's®",
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'F5713I05G-K11',
#    'name': 'Bottines - dark blue',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['24', '25', '26', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'friboo-bottines-dark-blue-f5713i05g-k11',
#    'media': [{'path': 'F5/71/3I/05/GK/11/F5713I05G-K11@9.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Friboo',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'GU124G050-A11',
#    'name': 'T-shirt à manches longues - true white',
#    'price': {'original': '18,95\xa0€',
#     'promotional': '13,25\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'guess-core-t-shirt-a-manches-longues-gu124g050-a11',
#    'media': [{'path': 'GU/12/4G/05/0A/11/GU124G050-A11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Guess',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NA313E02O-J12',
#    'name': 'COCOON - Chaussures premiers pas - rosa',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '34,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['18', '20', '21', '22', '23', '24', '25', '26'],
#    'url_key': 'naturino-cocoon-chaussures-a-scratch-na313e02o-j12',
#    'media': [{'path': 'NA/31/3E/02/OJ/12/NA313E02O-J12@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Naturino',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224G041-A11',
#    'name': 'SHORT SLEEVED COLLAR - Polo - flour/navy blue-alizarin',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '46,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '8a', '10a', '12a', '14a'],
#    'url_key': 'lacoste-short-sleeved-collar-polo-flournavy-blue-alizarin-la224g041-a11',
#    'media': [{'path': 'LA/22/4G/04/1A/11/LA224G041-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0LZ-A11',
#    'name': 'STAN SMITH - Baskets basses - footwear white/core black',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '51,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-footwear-whitecore-black-ad116d0lz-a11',
#    'media': [{'path': 'AD/11/6D/0L/ZA/11/AD116D0LZ-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0B7-Q11',
#    'name': 'AIR MAX 97 RFT  - Baskets basses - black/atmosphere grey/gunsmoke',
#    'price': {'original': '144,95\xa0€',
#     'promotional': '86,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-97-rft-baskets-basses-blackatmosphere-greygunsmoke-ni114d0b7-q11',
#    'media': [{'path': 'NI/11/4D/0B/7Q/11/NI114D0B7-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D00A-A11',
#    'name': 'SUPERSTAR - Baskets basses - white/core black',
#    'price': {'original': '69,95\xa0€',
#     'promotional': '45,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3', '38 2/3'],
#    'url_key': 'adidas-originals-superstar-baskets-basses-blanc-ad116d00a-a11',
#    'media': [{'path': 'AD/11/6D/00/AA/11/AD116D00A-A11@18.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116F009-Q11',
#    'name': 'SAMBA - Baskets basses - core black/footwear white',
#    'price': {'original': '44,95\xa0€',
#     'promotional': '26,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['19', '20', '21', '22', '23', '24', '25', '26', '27'],
#    'url_key': 'adidas-originals-samba-baskets-basses-core-blackfootwear-white-ad116f009-q11',
#    'media': [{'path': 'AD/11/6F/00/9Q/11/AD116F009-Q11@13.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224K015-K11',
#    'name': 'veste en sweat zippée - navy blue/silver chine',
#    'price': {'original': '99,95\xa0€',
#     'promotional': '64,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3y', '4a', '5a', '6a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-veste-en-sweat-zippee-navy-bluesilver-chine-la224k015-k11',
#    'media': [{'path': 'LA/22/4K/01/5K/11/LA224K015-K11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0MP-A12',
#    'name': 'STAN SMITH - Baskets basses - footwear white/glow pink',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '48,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['36', '38', '35 1/2', '36 2/3', '37 1/3'],
#    'url_key': 'adidas-originals-stan-smith-baskets-basses-ad116d0mp-a12',
#    'media': [{'path': 'AD/11/6D/0M/PA/12/AD116D0MP-A12@14.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -25%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'LA224G043-M11',
#    'name': 'PJ9424 - Polo - beeche/silver chine',
#    'price': {'original': '74,95\xa0€',
#     'promotional': '37,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '4a', '5a', '6a', '8a', '12a', '14a', '16a'],
#    'url_key': 'lacoste-long-sleeved-collar-shirt-t-shirt-a-manches-longues-beechesilver-chine-la224g043-m11',
#    'media': [{'path': 'LA/22/4G/04/3M/11/LA224G043-M11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Lacoste',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0N0-A11',
#    'name': 'YUNG-96 CHASM - Baskets basses - footwear white/crystal white',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '31', '32', '33', '35'],
#    'url_key': 'adidas-originals-yung-96-chasm-baskets-basses-footwear-whitecrystal-white-ad116d0n0-a11',
#    'media': [{'path': 'AD/11/6D/0N/0A/11/AD116D0N0-A11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'N1243A0ZC-Q11',
#    'name': "PICO 5 - Chaussures d'entraînement et de fitness - black",
#    'price': {'original': '29,95\xa0€',
#     'promotional': '23,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-performance-pico-5-chaussures-dentrainement-et-de-fitness-n1243a0zc-q11',
#    'media': [{'path': 'N1/24/3A/0Z/CQ/11/N1243A0ZC-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Performance',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI123D00E-Q11',
#    'name': 'ALL DAY PLAY COVERALL BABY - Combinaison - black',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '24,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-3a', '3a', '6a', '9a'],
#    'url_key': 'nike-sportswear-all-day-play-coverall-baby-combinaison-ni123d00e-q11',
#    'media': [{'path': 'NI/12/3D/00/EQ/11/NI123D00E-Q11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI113F00M-C11',
#    'name': 'AIR MAX AXIS - Mocassins - wolf grey/celestine blue/metallic dark grey/white',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '35,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['17', '18.5', '19.5', '21', '22', '23.5', '25', '26', '27'],
#    'url_key': 'nike-sportswear-air-max-axis-baskets-basses-ni113f00m-c11',
#    'media': [{'path': 'NI/11/3F/00/MC/11/NI113F00M-C11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI124D00T-K11',
#    'name': 'CHEVRON COVERALL BABY - Combinaison - mountain blue',
#    'price': {'original': '31,95\xa0€',
#     'promotional': '17,55\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['0-3a', '3a', '6a', '9a'],
#    'url_key': 'nike-sportswear-chevron-coverall-baby-combinaison-ni124d00t-k11',
#    'media': [{'path': 'NI/12/4D/00/TK/11/NI124D00T-K11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-45%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'CO413I000-J11',
#    'name': 'CHUCK TAYLOR ALL STAR - Baskets montantes - rust pink/burnt caramel',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '48,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27', '30', '31', '32', '33', '34', '37', '37.5', '38', '38.5'],
#    'url_key': 'converse-chuck-taylor-all-star-baskets-montantes-rust-pinkburnt-caramel-co413i000-j11',
#    'media': [{'path': 'CO/41/3I/00/0J/11/CO413I000-J11@11.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'},
#     {'key': 'specialOffer',
#      'value': 'Exclusivité',
#      'tracking_value': 'special offer'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0B9-K11',
#    'name': 'AIR MAX 200 - Baskets basses - royal pulse/oil grey/light aqua/ember glow',
#    'price': {'original': '104,95\xa0€',
#     'promotional': '62,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-max-200-baskets-basses-ni114d0b9-k11',
#    'media': [{'path': 'NI/11/4D/0B/9K/11/NI114D0B9-K11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'CO424L009-Q11',
#    'name': "WORDMARK QUILTED JACKET - Veste d'hiver - black",
#    'price': {'original': '64,95\xa0€',
#     'promotional': '32,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['3-4a',
#     '4-5a',
#     '5-6a',
#     '6-7a',
#     '8-10a',
#     '10-12a',
#     '12-13a',
#     '13-15a'],
#    'url_key': 'converse-wordmark-quilted-jacket-veste-dhiver-black-co424l009-q11',
#    'media': [{'path': 'CO/42/4L/00/9Q/11/CO424L009-Q11@2.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Converse',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-50%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'GU124K013-C11',
#    'name': 'Sweatshirt - light heather grey',
#    'price': {'original': '34,95\xa0€',
#     'promotional': '24,45\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['7a', '8a', '10a', '12a', '14a', '16a', '18a'],
#    'url_key': 'guess-core-sweatshirt-light-heather-grey-gu124k013-c11',
#    'media': [{'path': 'GU/12/4K/01/3C/11/GU124K013-C11@8.1.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Guess',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-30%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D09F-G11',
#    'name': 'AIR MAX MOTION 2 - Mocassins - team red/bright crimson/black/white',
#    'price': {'original': '59,95\xa0€',
#     'promotional': '50,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['27.5',
#     '28',
#     '28.5',
#     '29.5',
#     '30',
#     '31',
#     '31.5',
#     '32',
#     '33',
#     '33.5',
#     '34',
#     '35'],
#    'url_key': 'nike-sportswear-air-max-motion-2-baskets-basses-ni114d09f-g11',
#    'media': [{'path': 'NI/11/4D/09/FG/11/NI114D09F-G11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'TO124I02G-K11',
#    'name': 'BOYS OXFORD  - Chemise - blue',
#    'price': {'original': '49,95\xa0€',
#     'promotional': '42,45\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '6a', '7a', '8a', '10a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-boys-oxford-chemise-to124i02g-k11',
#    'media': [{'path': 'TO/12/4I/02/GK/11/TO124I02G-K11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-15%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'TO123G04J-K11',
#    'name': 'GIRLS BASIC  - T-shirt basique - sky captain',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '11,20\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['4a', '5a', '6a', '7a', '8a', '10a', '12a', '14a', '16a'],
#    'url_key': 'tommy-hilfiger-girls-basic-t-shirt-basique-to123g04j-k11',
#    'media': [{'path': 'TO/12/3G/04/JK/11/TO123G04J-K11@6.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': True}],
#    'brand_name': 'Tommy Hilfiger',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-25%',
#      'tracking_value': 'discount rate'},
#     {'key': 'csr',
#      'value': 'Éco-responsable',
#      'tracking_value': 'sustainable'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'NI114D0A1-A12',
#    'name': 'REACT PRESTO - Baskets basses - white',
#    'price': {'original': '94,95\xa0€',
#     'promotional': '56,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-react-presto-baskets-basses-ni114d0a1-a12',
#    'media': [{'path': 'NI/11/4D/0A/1A/12/NI114D0A1-A12@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI114D0CC-Q11',
#    'name': 'AIR FORCE 1 - Baskets basses - black/gold',
#    'price': {'original': '84,95\xa0€',
#     'promotional': '67,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-air-force-1-baskets-basses-blackgold-ni114d0cc-q11',
#    'media': [{'path': 'NI/11/4D/0C/CQ/11/NI114D0CC-Q11@8.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': 'HOT DROP',
#      'tracking_value': 'kids_sneaker_releases'},
#     {'key': 'discountRate',
#      'value': '-20%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI113D07Y-Q11',
#    'name': 'RENEW LUCENT - Baskets basses - black/white',
#    'price': {'original': '64,95\xa0€',
#     'promotional': '38,95\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': True,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['35.5', '36', '36.5', '37.5', '38', '38.5', '39', '40'],
#    'url_key': 'nike-sportswear-renew-lucent-baskets-basses-ni113d07y-q11',
#    'media': [{'path': 'NI/11/3D/07/YQ/11/NI113D07Y-Q11@3.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': 'Jusqu’à -40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'NI124G00J-K11',
#    'name': 'TEE BABY - T-shirt imprimé - obsidian',
#    'price': {'original': '14,95\xa0€',
#     'promotional': '8,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['12a', '18a', '24a'],
#    'url_key': 'nike-sportswear-tee-baby-t-shirt-imprime-obsidian-ni124g00j-k11',
#    'media': [{'path': 'NI/12/4G/00/JK/11/NI124G00J-K11@12.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Nike Sportswear',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'M8523K02H-A11',
#    'name': 'MARLEE - Sweatshirt - white/blue',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '35,65\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['2a', '3a', '4a', '6a', '7a', '8a', '10a', '12a'],
#    'url_key': 'molo-marlee-sweatshirt-whiteblue-m8523k02h-a11',
#    'media': [{'path': 'M8/52/3K/02/HA/11/M8523K02H-A11@4.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'Molo',
#    'is_premium': True,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-35%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'clothing',
#    'delivery_promises': []},
#   {'sku': 'AD116D0N6-A11',
#    'name': 'CONTINENTAL 80 - Baskets basses - offwhite/true pink/hi res aqua',
#    'price': {'original': '54,95\xa0€',
#     'promotional': '32,95\xa0€',
#     'has_different_prices': False,
#     'has_different_original_prices': False,
#     'has_different_promotional_prices': False,
#     'has_discount_on_selected_sizes_only': False},
#    'sizes': ['28', '29', '30', '31', '32', '33', '34'],
#    'url_key': 'adidas-originals-continental-80-baskets-basses-ad116d0n6-a11',
#    'media': [{'path': 'AD/11/6D/0N/6A/11/AD116D0N6-A11@7.jpg',
#      'role': 'DEFAULT',
#      'packet_shot': False}],
#    'brand_name': 'adidas Originals',
#    'is_premium': False,
#    'family_articles': [],
#    'flags': [{'key': 'campaign',
#      'value': '-20% EXTRA',
#      'tracking_value': 'fr_aw19_fresh_days_2019_49'},
#     {'key': 'discountRate',
#      'value': '-40%',
#      'tracking_value': 'discount rate'}],
#    'product_group': 'shoe',
#    'delivery_promises': []},
#   {'sku': 'AD116D0M5-K11',
#    'name': 'FOREST GROVE - Baskets basses - legend marine/collegiate burgundy',
#    'price': {'original': '48,95\xa0€',
#     'promotional': '26,85\xa0€',
#     'has_different_prices': True,
#     'has_different_original_prices': False,
# ...
#    'values': [{'key': 'BUSINESS', 'label': 'business'},
#     {'key': 'LOUNGE_WEAR', 'label': 'confort/maison'},
#     {'key': 'OCTOBER_FEST', 'label': 'festival de la bière'},
#     {'key': 'EVENING', 'label': 'festive'},
#     {'key': 'BRIDAL', 'label': 'Looks de mariée'},
#     {'key': 'PARTY', 'label': 'soirée'},
#     {'key': 'LEISURE', 'label': 'sortie/détente'}]},
#   {'key': 'assortment_areas',
#    'label': 'Coupes',
#    'url_key': 'assortment_area',
#    'kind': 'values',
#    'values': [{'key': 'STANDARD', 'label': 'Standard'},
#     {'key': 'MATERNITY', 'label': 'Maternité'}]},
#   {'key': 'seasons',
#    'label': 'Saison',
#    'url_key': 'season_name',
#    'kind': 'values',
#    'values': [{'key': 'SUMMER', 'label': 'Printemps/Été'},
#     {'key': 'WINTER', 'label': 'Automne/Hiver'}]},
#   {'key': 'campaigns',
#    'label': 'Sélections',
#    'url_key': 'camp',
#    'kind': 'values',
#    'values': [{'key': 'fr_aw19_fresh_days_2019_49', 'label': '-20% EXTRA'},
#     {'key': 'kids_comics_cartoons', 'label': 'BD et dessins animés'},
#     {'key': 'kids_sneaker_releases', 'label': 'Hot Sneaker Drops'},
#     {'key': 'mu_sneaker_releases', 'label': 'Hot Sneaker Drops'}]}],
#  'total_article_count': 25791,
#  'plusStatus': 'unknown',
#  'categoryTree': [{'label': 'Promos',
#    'id': '9574',
#    'url_key': 'promo-enfant',
#    'has_skus': True,
#    'selected': True,
#    'has_children': True,
#    'full_url': '/promo-enfant/?order=sale',
#    'children': [{'label': 'Vêtements',
#      'id': '9579',
#      'url_key': 'promo-mode-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-mode-enfant/?order=sale',
#      'children': [],
#      'article_count': 16908},
#     {'label': 'Chaussures',
#      'id': '9575',
#      'url_key': 'promo-chaussures-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-chaussures-enfant/?order=sale',
#      'children': [],
#      'article_count': 6110},
#     {'label': 'Sport',
#      'id': '14007',
#      'url_key': 'promo-sport-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-sport-enfant/?order=sale',
#      'children': [],
#      'article_count': 3638},
#     {'label': 'Sacs et accessoires',
#      'id': '9609',
#      'url_key': 'promo-accessoires-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-accessoires-enfant/?order=sale',
#      'children': [],
#      'article_count': 1657},
#     {'label': 'Luxe',
#      'id': '148690440',
#      'url_key': 'promo-luxe-enfant',
#      'has_skus': True,
#      'selected': False,
#      'has_children': True,
#      'full_url': '/promo-luxe-enfant/?order=sale',
#      'children': [],
#      'article_count': 2972}],
#    'article_count': 25789}],
#  'sortingKeys': [{'type': 'popularity', 'dir': 'desc', 'label': 'Préférés'},
#   {'type': 'activation_date', 'dir': 'desc', 'label': 'Nouveautés'},
#   {'type': 'price_asc', 'dir': 'asc', 'label': 'Prix croissant'},
#   {'type': 'price_desc', 'dir': 'desc', 'label': 'Prix décroissant'},
#   {'type': 'sale', 'dir': 'desc', 'label': 'Promos'}],
#  'breadcrumbs': [{'items': [{'label': 'Enfant',
#      'url_key': 'enfant',
#      'full_url': '/enfant/?order=sale'},
#     {'label': 'Promos',
#      'url_key': 'promo-enfant',
#      'full_url': '/promo-enfant/?order=sale'}]}],
#  'querySemantics': {'positive_filters': [{'key': 'categories',
#     'url_key': 'category',
#     'kind': 'values',
#     'values': [{'key': 'promo-enfant',
#       'url_key': 'promo-enfant',
#       'label': 'Promos',
#       'seo_label': 'Promotions enfant',
#       'reset_url': '/?order=sale',
#       'id': '9574'}]}],
#   'negative_filters': [],
#   'reset_query_url': '/promo-enfant/?order=sale',
#   'reset_url': '/promo-enfant/?order=sale',
#   'app_url': '?urlKey=promo-enfant&order=sale&appdomainId=11'},
#  'articlesToShow': 84,
#  'octopusTests': [],
#  'locale': 'fr-FR',
#  'isLoggedIn': False,
#  'notification': None,
#  'resetFilters': {'categories': [{'key': 'promo-enfant',
#     'url_key': 'promo-enfant',
#     'label': 'Promos',
#     'seo_label': 'Promotions enfant',
#     'reset_url': '/?order=sale',
#     'id': '9574'}]},
#  'selectedFilters': {'categories': ['promo-enfant']},
#  'ssrArticleCount': 32,
#  'feedbackId': '5c112594708a306b9e611805',
#  'variants': {'fullWidthCatalog': False,
#   'premiumCatalog': False,
#   'myBrandsFilter': True,
#   'hideCategories': False,
#   'mobileLightFilters': True,
#   'truncatedCount': False},
#  'contentPositions': {'in-cat-carousel': 9,
#   'in-cat-carousel-mobile': 6,
#   'in-cat-carousel-fullwidth': 8,
#   'in-cat-teaser': 9,
#   'upper-in-cat-teaser': 5,
#   'entry-point-teasers': [7, 14, 20, 26],
#   'in-grid-filter': 4,
#   'size-dialog': 12,
#   'sneaker-carousel': [12],
#   'outfits': [5, 14, 23],
#   'outfits-mobile': [5, 11, 17, 23],
#   'outfits-fullwidth': [7, 19, 31, 43]},
#  'prideEnabled': False,
#  'hideSearchTerm': False,
#  'iconPaths': {'filters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'mobileFilters': {'standard_delivery_filter': 'icons/truck.svg',
#    'fast_delivery_filter': 'icons/truck-fast.svg',
#    'zalando_plus': 'icons/plus-short-1.svg'},
#   'flags': {'slow_delivery_flag': 'icons/clock.svg',
#    'fast_delivery_flag': 'icons/truck-fast-orange-3.svg',
#    'plus_delivery_flag': 'icons/plus-short-1.svg',
#    'zalando_plus': 'icons/zalando-plus.svg'}},
#  'seoText': None,
#  'teaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/c8d725bf-5645-4a79-b407-c20344420c7c/81a484b6-c06d-498a-8ab4-fce5dc0277c4/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=e017d68d-2591-4645-986b-c4fcf62808e8&timeUnit=null&timeUnitCount=null&uuid=7c8f9b75-c82f-4f1f-9c25-89e55fa171fc&bid=null&requestId=bdf397e1-f9a9-4049-9cba-a499b1081535&s=A7C8C0CEB0B3A54BB7A7D7D296E7F3C5'],
#    'images': [{'aspect_ratio': None,
#      'max_screen_size': 1200,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/1600/299/3200/549/3500/spp-media-p1/97f5aca2acca45909e295273504f8fa6/a61ff6668ec149f8be6a9a4dc4f92b9d.jpeg',
#      'image_width': None},
#     {'aspect_ratio': None,
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/vgs/media/cropbyfocalarea/480/555/960/819/750/spp-media-p1/7c23cf18c10849218dd88c63ae1bb362/ad5b3193843c4b49ae2453204896be67.jpeg',
#      'image_width': None}],
#    'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8',
#    'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c',
#    'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#    'campaign_source_id': 'RQsmB4tXTAC',
#    'text_fields': {'cta': "J'en profite",
#     'bg_color': '#940000',
#     'legal_claim': "*Offre valable jusqu'au 17/12/2019 à 23h59 sur les articles soldés et les prix minis, à partir de 90€ d'achat.",
#     'voucher_code': 'STAYFRESH',
#     'title': "JUSQU'À -50% ET -20% EXTRA",
#     'type': 'sales',
#     'sales_template': 'Voucher',
#     'byline': 'Juste à temps pour Noël ⏰',
#     'voucher_label': 'Code promo*'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'category',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#       'brand_code': '-1',
#       'billing_method': 'CPV',
#       'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#       'flow_id': 'wy2joLHml5KW2T4-',
#       'price': 0.012428467245660331,
#       'shop_slot_id': 'catalog',
#       'campaign_source_id': 'RQsmB4tXTAC',
#       'request_id': 'bdf397e1-f9a9-4049-9cba-a499b1081535',
#       'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c',
#       'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8'}},
#     'view': {'type': 'teaser view',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'oCWj-YgNSJa',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'wy2joLHml5KW2T4-',
#        'price': 0.012428467245660331,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'bdf397e1-f9a9-4049-9cba-a499b1081535',
#        'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c'},
#       'dimension74': {'adId': 'oCWj-YgNSJa'}}},
#     'click': {'type': 'teaser click',
#      'category': 'category',
#      'label': 'catalog.teaser',
#      'id': 'RQsmB4tXTAC',
#      'name': "JUSQU'À -50% ET -20% EXTRA",
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'brand_code': '-1',
#        'billing_method': 'CPV',
#        'shop_slot_id': 'catalog',
#        'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8',
#        'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#        'adId': 'oCWj-YgNSJa',
#        'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#        'flow_id': 'wy2joLHml5KW2T4-',
#        'price': 0.012428467245660331,
#        'campaign_source_id': 'RQsmB4tXTAC',
#        'request_id': 'bdf397e1-f9a9-4049-9cba-a499b1081535',
#        'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c'},
#       'dimension74': {'adId': 'oCWj-YgNSJa'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/c8d725bf-5645-4a79-b407-c20344420c7c/81a484b6-c06d-498a-8ab4-fce5dc0277c4/creative.png?slotId=21672e65-4b93-4cd0-9943-404c19eece9a&creativeId=e017d68d-2591-4645-986b-c4fcf62808e8&timeUnit=null&timeUnitCount=null&uuid=c8e8b6ac-53dd-43f8-99af-a53234430738&bid=12&requestId=bdf397e1-f9a9-4049-9cba-a499b1081535&s=EBC62EADBAD39D720040A1E504B1DBFA'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'wy2joLHml5KW2T4-',
#      'entity_id': None,
#      'shop_slot_id': 'catalog',
#      'brand_code': '-1',
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c',
#      'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'brand_code': '-1',
#      'billing_method': 'CPV',
#      'shop_slot_id': 'catalog',
#      'creative_id': 'e017d68d-2591-4645-986b-c4fcf62808e8',
#      'campaign_name': 'CAMS_CAMS_-_FR_Fresh_Days_AW19_Sales_banners_FR_C_000000',
#      'adId': 'oCWj-YgNSJa',
#      'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a',
#      'flow_id': 'wy2joLHml5KW2T4-',
#      'price': 0.012428467245660331,
#      'campaign_source_id': 'RQsmB4tXTAC',
#      'request_id': 'bdf397e1-f9a9-4049-9cba-a499b1081535',
#      'campaign_id': 'c8d725bf-5645-4a79-b407-c20344420c7c'}},
#    'click_url': 'https://www.zalando.fr/promo-enfant/?camp=fr_aw19_fresh_days_2019_49&sale=true'},
#   'channel_name': 'CF',
#   'slot_id': '21672e65-4b93-4cd0-9943-404c19eece9a'},
#  'inCatalogTeaser': {'content': {'creative_format': 'TEASER',
#    'brand': {'name': 'non-fashion brand', 'code': '-1'},
#    'pixels': ['https://creativefactory.zalando.fr/impressions/c4b286d1-fd4b-4158-a08b-3b82a0041207/81a484b6-c06d-498a-8ab4-fce5dc0277c4/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=9f72cbcd-e544-4f3b-b2d2-641c2260a753&timeUnit=DAY&timeUnitCount=1&uuid=2b29d3cb-b8f5-4c5f-ac60-54c9d0f25400&bid=null&requestId=1f1507d3-3768-4f1c-8aed-33e27ed9aaea&s=5FFEDB180AD5A9E477DB3DCAC9047C6A'],
#    'images': [{'aspect_ratio': '9:13',
#      'max_screen_size': 600,
#      'image_url': 'https://mosaic03.ztat.net/crt/creative-content/a4a0109a-bfcd-418a-9e0c-f81eed67bf9c.jpg',
#      'image_width': 792}],
#    'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#    'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#    'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#    'text_fields': {'cta': 'Jusqu’à -50%',
#     'title': 'Sneakers',
#     'sales_template': 'None'},
#    'tracking_events': {'impression': {'type': 'advertising-event',
#      'advertising-category': 'catalog',
#      'advertising-action': 'teaser impression',
#      'advertising-parameter': {'channel_name': 'CF',
#       'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#       'brand_code': '-1',
#       'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#       'flow_id': 'wy2joLHml5KW2T4-',
#       'time_unit': 'DAY',
#       'time_unit_count': 1,
#       'shop_slot_id': 'in_catalog',
#       'campaign_source_id': 'undefined',
#       'request_id': '1f1507d3-3768-4f1c-8aed-33e27ed9aaea',
#       'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#       'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}},
#     'view': {'type': 'teaser view',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'name': 'Sneakers',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'wy2joLHml5KW2T4-',
#        'time_unit': 'DAY',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '1f1507d3-3768-4f1c-8aed-33e27ed9aaea',
#        'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#        'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}}},
#     'click': {'type': 'teaser click',
#      'category': 'catalog',
#      'label': 'in_catalog.teaser',
#      'id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'name': 'Sneakers',
#      'parameters': {'dimension172': {'channel_name': 'CF',
#        'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#        'brand_code': '-1',
#        'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#        'flow_id': 'wy2joLHml5KW2T4-',
#        'time_unit': 'DAY',
#        'time_unit_count': 1,
#        'shop_slot_id': 'in_catalog',
#        'campaign_source_id': 'undefined',
#        'request_id': '1f1507d3-3768-4f1c-8aed-33e27ed9aaea',
#        'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#        'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}}}},
#    'view_pixels': ['https://creativefactory.zalando.fr/views/c4b286d1-fd4b-4158-a08b-3b82a0041207/81a484b6-c06d-498a-8ab4-fce5dc0277c4/creative.png?slotId=cb224cac-736d-4e00-b757-d8a8007ef951&creativeId=9f72cbcd-e544-4f3b-b2d2-641c2260a753&timeUnit=DAY&timeUnitCount=1&uuid=b6c8456f-6701-4eb6-918f-f527fd2628ed&bid=null&requestId=1f1507d3-3768-4f1c-8aed-33e27ed9aaea&s=EBDE76DA2D7AC9FB15B86C6D8C46C50B'],
#    'tracking_data': {'explicit_tracking_params': {'flow_id': 'wy2joLHml5KW2T4-',
#      'entity_id': None,
#      'shop_slot_id': 'in_catalog',
#      'brand_code': '-1',
#      'campaign_source_id': None,
#      'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#      'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753',
#      'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#      'target_entity_id': None},
#     'cf_tracking_params': {'channel_name': 'CF',
#      'campaign_name': 'CM_KIDS_Risk_Sneakers_FR',
#      'brand_code': '-1',
#      'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951',
#      'flow_id': 'wy2joLHml5KW2T4-',
#      'time_unit': 'DAY',
#      'time_unit_count': 1,
#      'shop_slot_id': 'in_catalog',
#      'campaign_source_id': 'undefined',
#      'request_id': '1f1507d3-3768-4f1c-8aed-33e27ed9aaea',
#      'campaign_id': 'c4b286d1-fd4b-4158-a08b-3b82a0041207',
#      'creative_id': '9f72cbcd-e544-4f3b-b2d2-641c2260a753'}},
#    'click_url': 'https://www.zalando.fr/collections/Sqklq-J7RqK/?order=sale'},
#   'channel_name': 'CF',
#   'slot_id': 'cb224cac-736d-4e00-b757-d8a8007ef951'},
#  'entryPointTeasers': None,
#  'upperInCatTeaser': None,
#  'collection': None,
#  'carouselTeaser': None,
#  'wishlist': None,
#  'pills': None,
#  'sizeOnboardingDialog': None}

# %%
flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])

flattened_data1
# Out:
#               sku                                               name  \
# 0   AD116D0MY-A11  YUNG-96 CHASM - Baskets basses - footwear whit...
# 1   AD116D07G-A11  STAN SMITH CF I - Chaussures premiers pas - wh...
# 2   AD116D00X-A11  SUPERSTAR - Baskets basses - white/metallic si...
# 3   NI113D08S-J11  Baskets basses - pink foam/white/metallic plat...
# 4   LE224G080-C11  SPLIT TEE - T-shirt à manches longues - grey h...
# ..            ...                                                ...
# 79  NI126G00S-C11  TEE AIR HOOP SNOW - T-shirt imprimé - grey hea...
# 80  1FI26G001-Q11      KIDS ZOE STRIPE TEE - T-shirt imprimé - black
# 81  GP024G0GK-A11          BOY MAY - T-shirt imprimé - new off white
# 82  NI114D0CE-C11  AIR MAX 200 WTR - Baskets basses - dark grey/m...
# 83  AD116D0O3-A11  SUPERCOURT - Baskets basses - footwear white/c...
#
#                                                 sizes  \
# 0   [36, 38, 40, 35 1/2, 36 2/3, 37 1/3, 38 2/3, 3...
# 1   [19, 20, 21, 22, 23, 24, 25, 26, 27, 23 1/2, 2...
# 2            [36, 38, 35 1/2, 36 2/3, 37 1/3, 38 2/3]
# 3                    [35.5, 36, 36.5, 37.5, 38, 38.5]
# 4            [2a, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# ..                                                ...
# 79                  [6-7a, 8-9a, 10-11a, 12-13a, 14a]
# 80             [3-4a, 5-6a, 7-8a, 9-10a, 11-12a, 24m]
# 81               [4-5a, 8-9a, 10-11a, 12-13a, 14-16a]
# 82           [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40]
# 83                       [21, 22, 23, 24, 25, 26, 27]
#
#                                               url_key  \
# 0   adidas-originals-yung-96-chasm-baskets-basses-...
# 1   adidas-originals-stan-smith-cf-i-baskets-basse...
# 2   adidas-originals-superstar-baskets-basses-whit...
# 3   nike-sportswear-baskets-basses-pink-foamwhitem...
# 4   levisr-split-tee-t-shirt-a-manches-longues-gre...
# ..                                                ...
# 79  nike-sportswear-tee-hoop-snow-t-shirt-imprime-...
# 80  fila-kids-zoe-stripe-tee-t-shirt-imprime-black...
# 81  gap-boy-may-t-shirt-imprime-new-off-white-gp02...
# 82  nike-sportswear-air-max-200-wtr-baskets-basses...
# 83  adidas-originals-supercourt-baskets-basses-foo...
#
#                                                 media        brand_name  \
# 0   [{'path': 'AD/11/6D/0M/YA/11/AD116D0MY-A11@7.j...  adidas Originals
# 1   [{'path': 'AD/11/6D/07/GA/11/AD116D07G-A11@12....  adidas Originals
# 2   [{'path': 'AD/11/6D/00/XA/11/AD116D00X-A11@12....  adidas Originals
# 3   [{'path': 'NI/11/3D/08/SJ/11/NI113D08S-J11@9.j...   Nike Sportswear
# 4   [{'path': 'LE/22/4G/08/0C/11/LE224G080-C11@2.j...           Levi's®
# ..                                                ...               ...
# 79  [{'path': 'NI/12/6G/00/SC/11/NI126G00S-C11@5.j...   Nike Sportswear
# 80  [{'path': '1F/I2/6G/00/1Q/11/1FI26G001-Q11@7.j...              Fila
# 81  [{'path': 'GP/02/4G/0G/KA/11/GP024G0GK-A11@7.j...               GAP
# 82  [{'path': 'NI/11/4D/0C/EC/11/NI114D0CE-C11@10....   Nike Sportswear
# 83  [{'path': 'AD/11/6D/0O/3A/11/AD116D0O3-A11@8.j...  adidas Originals
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 1   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 2   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 3   [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
# 4   [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 81  [{'key': 'campaign', 'value': '-20% EXTRA', 't...      clothing
# 82  [{'key': 'campaign', 'value': 'HOT DROP', 'tra...          shoe
# 83  [{'key': 'campaign', 'value': '-20% EXTRA', 't...          shoe
#
#    delivery_promises price.original price.promotional  \
# 0                 []        79,95 €           51,95 €
# 1                 []        49,95 €           39,95 €
# 2                 []        69,95 €           41,95 €
# 3                 []       139,95 €           97,95 €
# 4                 []        24,95 €           14,95 €
# ..               ...            ...               ...
# 79                []        24,95 €           12,45 €
# 80                []        24,95 €           12,45 €
# 81                []        11,95 €            7,15 €
# 82                []        99,95 €           59,95 €
# 83                []        49,95 €           32,45 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                         True                                False
# 1                         True                                False
# 2                         True                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
# [84 rows x 17 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    #response = requests.get(url)
    response = requests.get(url, headers=headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1, sort=False)

df
# Out:
#                                                             name  \
# sku
# NI114D056-Q11         COURT BOROUGH  - Baskets montantes - black
# NI113D08E-Q11  AIR MAX 270 REACT - Mocassins - black/white/hy...
# TO124G05S-Q11          BOYS BASIC  - T-shirt basique - meteorite
# NI114D058-Q11             COURT BOROUGH - Baskets basses - black
# LA224G047-K11              BOY TEE - T-shirt imprimé - navy blue
# ...                                                          ...
# KE543A08W-L12  CHANDLER CNX - Chaussures de marche - tahitian...
# CO414D078-I11  CHUCK TAYLOR ALL STAR - Baskets montantes - wa...
# AD543A200-Q11  COPA 19.3 FG - Chaussures de foot à crampons -...
# AD543A1ZP-Q11  COPA 19.4 TF - Chaussures de foot multicrampon...
# L0643D00P-K11  TENNIS DJOKOVIC - T-shirt de sport - navy blue...
#
#                                                       sizes  \
# sku
# NI114D056-Q11      [28, 28.5, 29.5, 30, 31, 32, 33, 34, 35]
# NI113D08E-Q11                    [28.5, 29.5, 30, 31.5, 34]
# TO124G05S-Q11      [4a, 5a, 6a, 7a, 8a, 10a, 12a, 14a, 16a]
# NI114D058-Q11  [27.5, 28.5, 30, 31.5, 32, 33, 33.5, 34, 35]
# LA224G047-K11  [2a, 3y, 4a, 5a, 6a, 8a, 10a, 12a, 14a, 16a]
# ...                                                     ...
# KE543A08W-L12                                  [37, 38, 39]
# CO414D078-I11                                      [32, 35]
# AD543A200-Q11                                  [38, 37 1/3]
# AD543A1ZP-Q11                              [36, 38, 38 2/3]
# L0643D00P-K11                                     [8a, 12a]
#
#                                                          url_key  \
# sku
# NI114D056-Q11  nike-sportswear-court-borough-baskets-montante...
# NI113D08E-Q11  nike-sportswear-air-max-270-react-baskets-bass...
# TO124G05S-Q11  tommy-hilfiger-boys-basic-t-shirt-basique-to12...
# NI114D058-Q11  nike-sportswear-baskets-basses-black-ni114d058...
# LA224G047-K11      lacoste-boy-tee-t-shirt-imprime-la224g047-k11
# ...                                                          ...
# KE543A08W-L12  keen-chandler-cnx-chaussures-de-randonnee-ke54...
# CO414D078-I11  converse-chuck-taylor-all-star-baskets-montant...
# AD543A200-Q11  adidas-performance-copa-193-fg-chaussures-de-f...
# AD543A1ZP-Q11  adidas-performance-copa-194-tf-chaussures-de-f...
# L0643D00P-K11  lacoste-sport-tennis-djokovic-polo-navy-blueto...
#
#                                                            media  \
# sku
# NI114D056-Q11  [{'path': 'NI/11/4D/05/6Q/11/NI114D056-Q11@12....
# NI113D08E-Q11  [{'path': 'NI/11/3D/08/EQ/11/NI113D08E-Q11@5.j...
# TO124G05S-Q11  [{'path': 'TO/12/4G/05/SQ/11/TO124G05S-Q11@6.j...
# NI114D058-Q11  [{'path': 'NI/11/4D/05/8Q/11/NI114D058-Q11@12....
# LA224G047-K11  [{'path': 'LA/22/4G/04/7K/11/LA224G047-K11@6.j...
# ...                                                          ...
# KE543A08W-L12  [{'path': 'KE/54/3A/08/WL/12/KE543A08W-L12@3.j...
# CO414D078-I11  [{'path': 'CO/41/4D/07/8I/11/CO414D078-I11@8.j...
# AD543A200-Q11  [{'path': 'AD/54/3A/20/0Q/11/AD543A200-Q11@3.j...
# AD543A1ZP-Q11  [{'path': 'AD/54/3A/1Z/PQ/11/AD543A1ZP-Q11@8.j...
# L0643D00P-K11  [{'path': 'L0/64/3D/00/PK/11/L0643D00P-K11@9.j...
#
#                        brand_name  is_premium family_articles  \
# sku
# NI114D056-Q11     Nike Sportswear       False              []
# NI113D08E-Q11     Nike Sportswear       False              []
# TO124G05S-Q11      Tommy Hilfiger        True              []
# NI114D058-Q11     Nike Sportswear       False              []
# LA224G047-K11             Lacoste        True              []
# ...                           ...         ...             ...
# KE543A08W-L12                Keen       False              []
# CO414D078-I11            Converse       False              []
# AD543A200-Q11  adidas Performance       False              []
# AD543A1ZP-Q11  adidas Performance       False              []
# L0643D00P-K11       Lacoste Sport       False              []
#
#                                                            flags  \
# sku
# NI114D056-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# NI113D08E-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# TO124G05S-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# NI114D058-Q11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# LA224G047-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
# ...                                                          ...
# KE543A08W-L12  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...
# CO414D078-I11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...
# AD543A200-Q11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...
# AD543A1ZP-Q11  [{'key': 'campaign', 'value': 'PRIX MINI', 'tr...
# L0643D00P-K11  [{'key': 'campaign', 'value': '-20% EXTRA', 't...
#
#               product_group delivery_promises price.original  \
# sku
# NI114D056-Q11          shoe                []        44,95 €
# NI113D08E-Q11          shoe                []        94,95 €
# TO124G05S-Q11      clothing                []        14,95 €
# NI114D058-Q11          shoe                []        34,95 €
# LA224G047-K11      clothing                []        38,95 €
# ...                     ...               ...            ...
# KE543A08W-L12          shoe                []        47,95 €
# CO414D078-I11          shoe                []        39,95 €
# AD543A200-Q11          shoe                []        31,95 €
# AD543A1ZP-Q11          shoe                []        27,95 €
# L0643D00P-K11      clothing                []        70,00 €
#
#               price.promotional  price.has_different_prices  \
# sku
# NI114D056-Q11           26,95 €                        True
# NI113D08E-Q11           56,95 €                        True
# TO124G05S-Q11           11,20 €                        True
# NI114D058-Q11           27,95 €                       False
# LA224G047-K11           19,45 €                        True
# ...                         ...                         ...
# KE543A08W-L12           47,95 €                        True
# CO414D078-I11           39,95 €                        True
# AD543A200-Q11           31,95 €                        True
# AD543A1ZP-Q11           27,95 €                        True
# L0643D00P-K11           70,00 €                        True
#
#                price.has_different_original_prices  \
# sku
# NI114D056-Q11                                False
# NI113D08E-Q11                                False
# TO124G05S-Q11                                False
# NI114D058-Q11                                False
# LA224G047-K11                                False
# ...                                            ...
# KE543A08W-L12                                 True
# CO414D078-I11                                 True
# AD543A200-Q11                                 True
# AD543A1ZP-Q11                                 True
# L0643D00P-K11                                 True
#
#                price.has_different_promotional_prices  \
# sku
# NI114D056-Q11                                    True
# NI113D08E-Q11                                    True
# TO124G05S-Q11                                    True
# NI114D058-Q11                                   False
# LA224G047-K11                                    True
# ...                                               ...
# KE543A08W-L12                                   False
# CO414D078-I11                                   False
# AD543A200-Q11                                   False
# AD543A1ZP-Q11                                   False
# L0643D00P-K11                                   False
#
#                price.has_discount_on_selected_sizes_only amount  \
# sku
# NI114D056-Q11                                      False    NaN
# NI113D08E-Q11                                      False    NaN
# TO124G05S-Q11                                      False    NaN
# NI114D058-Q11                                      False    NaN
# LA224G047-K11                                      False    NaN
# ...                                                  ...    ...
# KE543A08W-L12                                      False    NaN
# CO414D078-I11                                      False    NaN
# AD543A200-Q11                                      False    NaN
# AD543A1ZP-Q11                                      False    NaN
# L0643D00P-K11                                      False    NaN
#
#               price.base_price
# sku
# NI114D056-Q11              NaN
# NI113D08E-Q11              NaN
# TO124G05S-Q11              NaN
# NI114D058-Q11              NaN
# LA224G047-K11              NaN
# ...                        ...
# KE543A08W-L12              NaN
# CO414D078-I11              NaN
# AD543A200-Q11              NaN
# AD543A1ZP-Q11              NaN
# L0643D00P-K11              NaN
#
# [25786 rows x 18 columns]

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'OVS'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Nike Sportswear'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)
