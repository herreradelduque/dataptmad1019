# %% [markdown]
# # Challenge 3

# %%
# import libraries here
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import cufflinks as cf
import plotly.express as px

# %% [markdown]
# Plotly offline:

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #### Import the titanic file. Name your dataset `titanic`.

# %%
titanic = pd.read_csv('./titanic.csv',low_memory=False)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500    U0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250    U0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500    U0        S

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes

# %%
#your code here
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
#
# *Hint: Use Pandas `select_dtypes`*

# %%
# your code here- numerical variable
numerical = ['int', 'float']
titanic.select_dtypes(numerical).head()

#another way:
#titanic.select_dtypes(exclude = object)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1       0.0       3  22.0      1      0   7.2500
# 1            2       1.0       1  38.0      1      0  71.2833
# 2            3       1.0       3  26.0      0      0   7.9250
# 3            4       1.0       1  35.0      1      0  53.1000
# 4            5       0.0       3  35.0      0      0   8.0500

# %%
#your code here- categorical variable
titanic.select_dtypes(object).head()

#another way:
#titanic.select_dtypes(exclude = ['int', 'float']).head()
# Out:
#                                                 Name  Gender  \
# 0                            Braund, Mr. Owen Harris    male
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male
#
#              Ticket Cabin Embarked
# 0         A/5 21171    U0        S
# 1          PC 17599   C85        C
# 2  STON/O2. 3101282    U0        S
# 3            113803  C123        S
# 4            373450    U0        S

# %% [markdown]
# #### Set the plot style to `classic` and the figure size to `(12,6)`
#
# *Hint: To set the style you can use `matplotlib.pyplot` functions or seaborn*

# %%
# your code here
print(plt.style.available)
plt.style.use('classic')
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %% [markdown]
# #### Use the appropriate visulalization to show the distribution of the column `Age`

# %%
# your code here
titanic['Age'].hist(bins=8)

# %% [markdown]
# plotly express way:

# %%
px.histogram(data_frame=titanic,
             x='Age',
             nbins=8)
# Out:
# <div>
#
#
#             <div id="7cbd7fb6-8e74-4bdf-9411-0c8c62756880" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7cbd7fb6-8e74-4bdf-9411-0c8c62756880")) {
#                     Plotly.newPlot(
#                         '7cbd7fb6-8e74-4bdf-9411-0c8c62756880',
# ...

# %% [markdown]
# #### Use subplots to plot the distribution of the `Age` variable with bins equal to `10`, `20` and `50`.

# %%
# your code here
plt.subplot(1,3,1)
titanic['Age'].hist()
plt.subplot(1,3,2)
titanic['Age'].hist(bins=20)
plt.subplot(1,3,3)
titanic['Age'].hist(bins=50)

# %% [markdown]
# #### Whether the bin size affects your plot? Why?

# %%
#your comment here

#The less bins there are the taller bars there are.

# %% [markdown]
# plotly express way:

# %%
px.histogram(data_frame=titanic,
             x='Age',
             nbins=10)
# Out:
# <div>
#
#
#             <div id="09a7603c-4d7e-4150-aaa6-7a012871753e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("09a7603c-4d7e-4150-aaa6-7a012871753e")) {
#                     Plotly.newPlot(
#                         '09a7603c-4d7e-4150-aaa6-7a012871753e',
# ...

# %%
px.histogram(data_frame=titanic,
             x='Age',
             nbins=20)
# Out:
# <div>
#
#
#             <div id="e2fbd76d-e606-4cad-a965-5e4aeaf65e81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e2fbd76d-e606-4cad-a965-5e4aeaf65e81")) {
#                     Plotly.newPlot(
#                         'e2fbd76d-e606-4cad-a965-5e4aeaf65e81',
# ...

# %%
px.histogram(data_frame=titanic,
             x='Age',
             nbins=50)
# Out:
# <div>
#
#
#             <div id="2f53294d-7081-4887-9093-1bd497c964cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2f53294d-7081-4887-9093-1bd497c964cf")) {
#                     Plotly.newPlot(
#                         '2f53294d-7081-4887-9093-1bd497c964cf',
# ...

# %% [markdown]
# #### Use seaborn to show the distribution of the column `Age`

# %%
# your code here
sns.distplot(titanic['Age'],bins=8,kde=False,color='red')

# %%
px.histogram(data_frame=titanic,
             x='Age',
             nbins=8)
# Out:
# <div>
#
#
#             <div id="34ca7417-9678-4f67-8497-1069c3f7be28" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("34ca7417-9678-4f67-8497-1069c3f7be28")) {
#                     Plotly.newPlot(
#                         '34ca7417-9678-4f67-8497-1069c3f7be28',
# ...

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Gender`. There are 2 ways of doing it. Do it both ways.
#
# *Hint: Use matplotlib and seaborn*

# %%
# your code here- 1st way
titanic['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Gender')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# your code here- 2nd way
sns.countplot(x='Gender',data=titanic)

# %% [markdown]
# plotly express way:

# %%
px.histogram(data_frame=titanic,
            x='Gender',
            )
# Out:
# <div>
#
#
#             <div id="808b8ccc-457b-44e8-9a97-b2759aa601e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("808b8ccc-457b-44e8-9a97-b2759aa601e0")) {
#                     Plotly.newPlot(
#                         '808b8ccc-457b-44e8-9a97-b2759aa601e0',
# ...

# %% [markdown]
# #### Use the appropriate plot to visualize the column `Pclass`

# %%
# your code here
sns.countplot('Pclass',data=titanic)

# %%
titanic['Pclass'].value_counts().plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ploty express way:

# %%
px.bar(data_frame=titanic,
            x='Pclass')
# Out:
# <div>
#
#
#             <div id="829ce4e6-1732-4b1c-980e-899eb8fcdaea" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("829ce4e6-1732-4b1c-980e-899eb8fcdaea")) {
#                     Plotly.newPlot(
#                         '829ce4e6-1732-4b1c-980e-899eb8fcdaea',
# ...

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. Choose the appropriate plot to show below.

# %%
# your code here
titanic.boxplot(column='Age')

# %% [markdown]
# cufflinks way:

# %%
titanic['Age'].iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="75923b99-57c4-4967-b2d9-94ce1bea82b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("75923b99-57c4-4967-b2d9-94ce1bea82b7")) {
#                     Plotly.newPlot(
#                         '75923b99-57c4-4967-b2d9-94ce1bea82b7',
# ...

# %% [markdown]
# #### What does the previous plot tell you about the feature `Age`? Comment.

# %%
# your comment here

# The Median is under 30
# The interquartilic range is between 22 to 37
# The minimun age (in years) is 0
# The maximun age is 59
# There exists some outliers from 60 to 80

# %% [markdown]
# #### Now in addition to the summary statistics, we also want to visualize the distribution of `Age`. Choose the appropriate plot to sow below.

# %%
#your code here
sns.violinplot('Age',data=titanic)

# %% [markdown]
# #### What additional information in the previous plot provide you about the feature `Age`? Comment.

# %%
#your comment here
# The Median is under 30
# Most data are located in range 22 to 37
# The minimun age (in years) is 0
# The maximun age is 59
# There exists some outliers

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the appropriate plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
#
# *Hint: One of the ways involves using Seaborn*

# %%
#your code-1st way
titanic.plot(kind='scatter',x='Fare',y='Age', figsize=(6.2,4), s=40)

# %% [markdown]
# plotly express way:

# %%
fig = px.scatter(titanic,x='Fare',y='Age')
fig.show()
# Out:
# <div>
#
#
#             <div id="e13ed34d-1e42-472a-baa1-8bf008a1f55e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e13ed34d-1e42-472a-baa1-8bf008a1f55e")) {
#                     Plotly.newPlot(
#                         'e13ed34d-1e42-472a-baa1-8bf008a1f55e',
# ...

# %%
# your code-2nd way
sns.jointplot(x='Fare',y='Age',data=titanic)

# %% [markdown]
# plotly express way:

# %%
fig = px.scatter(titanic, x='Fare',y='Age', marginal_y="histogram",
           marginal_x="histogram")
fig.show()
# Out:
# <div>
#
#
#             <div id="287c6c0e-0d5d-4094-9c98-944fe449df17" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("287c6c0e-0d5d-4094-9c98-944fe449df17")) {
#                     Plotly.newPlot(
#                         '287c6c0e-0d5d-4094-9c98-944fe449df17',
# ...

# %% [markdown]
# #### Using Seaborn plot the correlation matrix of various features.
#
# *Hint: search how to use `heatmap`*

# %%
#your code here
sns.heatmap(titanic.corr(),cmap='coolwarm')
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1, 'Correlation matrix')

# %% [markdown]
# cufflinks way:

# %%
titanic_cor= titanic.corr()
titanic_cor=titanic_cor.reset_index()
titanic_cor
# Out:
#          index  PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# 0  PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# 1     Survived    -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# 2       Pclass    -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# 3          Age     0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# 4        SibSp    -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# 5        Parch     0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# 6         Fare     0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#        Fare
# 0  0.031128
# 1  0.257307
# 2 -0.558683
# 3  0.171355
# 4  0.160349
# 5  0.221635
# 6  1.000000

# %%
px.imshow(titanic_cor.T.values, title='Correlation matrix')
# Out:
# <div>
#
#
#             <div id="2677ba8d-8ff0-474c-aa88-fa9f54b05cb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2677ba8d-8ff0-474c-aa88-fa9f54b05cb3")) {
#                     Plotly.newPlot(
#                         '2677ba8d-8ff0-474c-aa88-fa9f54b05cb3',
# ...

# %% [markdown]
# #### According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
#The most correlated feaures are: Parch <=> SibSp and Survived <=> Fare

# %% [markdown]
# #### Use the appropriate plot to display the summary statistics of the `Age` in function of the `Pclass`.
#
# *Hint: use boxplot to display summary statistics of `Age` in relation to each of the discrete values of `Pclass`*

# %%
#your code here
sns.boxplot(x='Pclass',y='Age',data=titanic,palette='rainbow')

# %% [markdown]
# plotly express way:

# %%
fig = px.box(titanic, x="Pclass", y="Age")
fig.show()
# Out:
# <div>
#
#
#             <div id="d79ab400-bb08-4366-b107-3c14dd233857" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d79ab400-bb08-4366-b107-3c14dd233857")) {
#                     Plotly.newPlot(
#                         'd79ab400-bb08-4366-b107-3c14dd233857',
# ...

# %% [markdown]
# #### Use the appropriate plot to display the distributions of  `Age` in relation to  `Gender`.
#
# *Hint: use Facetgrid to display the distribution of `Age` for each categorical value of `Gender`*

# %%
#your code here
g = sns.FacetGrid(data=titanic,col='Gender')
g.map(plt.hist,'Age')

# %%
titanic_filt_male = titanic[(titanic['Gender']=='male')]
titanic_filt_male.groupby('Age').head()
# Out:
#       PassengerId  Survived  Pclass                            Name Gender  \
# 0               1       0.0       3         Braund, Mr. Owen Harris   male
# 4               5       0.0       3        Allen, Mr. William Henry   male
# 5               6       0.0       3                Moran, Mr. James   male
# 6               7       0.0       1         McCarthy, Mr. Timothy J   male
# 7               8       0.0       3  Palsson, Master. Gosta Leonard   male
# ...           ...       ...     ...                             ...    ...
# 1278         1279       NaN       2                 Ashby, Mr. John   male
# 1280         1281       NaN       3     Palsson, Master. Paul Folke   male
# 1283         1284       NaN       3   Abbott, Master. Eugene Joseph   male
# 1306         1307       NaN       3    Saether, Mr. Simon Sivertsen   male
# 1308         1309       NaN       3        Peter, Master. Michael J   male
#
# ...

# %%
titanic_filt_female = titanic[(titanic['Gender']=='female')]
titanic_filt_female.groupby('Age').head()
# Out:
#       PassengerId  Survived  Pclass  \
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 8               9       1.0       3
# 9              10       1.0       2
# ...           ...       ...     ...
# 1273         1274       NaN       3
# 1282         1283       NaN       1
# 1299         1300       NaN       3
# 1300         1301       NaN       3
# 1302         1303       NaN       1
#
#                                                    Name  Gender        Age  \
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                   Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# ...

# %%
px.histogram(titanic_filt_male, x='Age',y='Gender',nbins=10, title='Males by age')
# Out:
# <div>
#
#
#             <div id="4cd2c37c-91b2-4bfc-8edf-84a3e510d98f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4cd2c37c-91b2-4bfc-8edf-84a3e510d98f")) {
#                     Plotly.newPlot(
#                         '4cd2c37c-91b2-4bfc-8edf-84a3e510d98f',
# ...

# %%
px.histogram(titanic_filt_female, x='Age',y='Gender',nbins=10, title='Females by age' )
# Out:
# <div>
#
#
#             <div id="a2d80e3a-5e2a-452c-9f55-a70f202dfd1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a2d80e3a-5e2a-452c-9f55-a70f202dfd1d")) {
#                     Plotly.newPlot(
#                         'a2d80e3a-5e2a-452c-9f55-a70f202dfd1d',
# ...
